# %%
import pandas as pd
import os
 
dirpath = os.getcwd()
dirpath
# Out:
# '/home/eduardo/Documentos/proyectos/project-shark-attacks'

# %%
df = pd.read_csv("../project-shark-attacks/Input/GSAF5.csv")

# %%
df.head(50)
# Out:
#      Case Number                   Date  Year        Type        Country  \
# 0   2016.09.18.c              18-Sep-16  2016  Unprovoked            USA
# 1   2016.09.18.b              18-Sep-16  2016  Unprovoked            USA
# 2   2016.09.18.a              18-Sep-16  2016  Unprovoked            USA
# 3     2016.09.17              17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4     2016.09.15              16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5   2016.09.15.R              15-Sep-16  2016        Boat      AUSTRALIA
# 6     2016.09.11              11-Sep-16  2016  Unprovoked            USA
# 7     2016.09.07              07-Sep-16  2016  Unprovoked            USA
# 8     2016.09.06              06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9   2016.09.05.b              05-Sep-16  2016  Unprovoked            USA
# 10  2016.09.05.a              05-Sep-16  2016  Unprovoked      AUSTRALIA
# 11    2016.09.04              04-Sep-16  2016  Unprovoked            USA
# ...

# %%
print(df.columns)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df = df.rename(columns={"Sex ": "Sex"})
df = df.rename(columns={"Species ": "Species"})

# %%
print(df.shape)
# Out:
# (5992, 24)

# %%
print(df.dtypes)
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# Unnamed: 22               object
# Unnamed: 23               object
# dtype: object

# %%
#Casos en España
spain_df = df[(df['Country']=='SPAIN')] 
spain_df
# Out:
#        Case Number                  Date  Year        Type Country  \
# 20      2016.07.29             29-Jul-16  2016  Unprovoked   SPAIN
# 34    2016.07.08.R  Reported 08-Jul-2016  2016  Unprovoked   SPAIN
# 104     2015.12.25             25-Dec-15  2015  Unprovoked   SPAIN
# 159   2015.08.18.a             18-Aug-15  2015     Invalid   SPAIN
# 249   2014.12.03.R  Reported 03-Dec-2014  2014    Provoked   SPAIN
# 282     2014.09.00                Sep-14  2014  Unprovoked   SPAIN
# 287   2014.08.27.c             27-Aug-14  2014  Unprovoked   SPAIN
# 307     2014.07.20             20-Jul-14  2014  Unprovoked   SPAIN
# 434     2013.07.09             07-Jul-13  2013     Invalid   SPAIN
# 788   2010.07.16.b             16-Jul-10  2010    Provoked   SPAIN
# 884   2009.07.24.a             24-Jul-09  2009     Invalid   SPAIN
# 1234    2006.07.13             13-Jul-06  2006     Invalid   SPAIN
# 2251    1993.09.03             03-Sep-93  1993  Unprovoked   SPAIN
# ...

# %%
spain_df2=spain_df[['Date', 'Year','Type','Area','Activity','Age','Injury','Fatal (Y/N)','Time','Species','Sex']]
spain_df2
# Out:
#                       Date  Year        Type                 Area  \
# 20               29-Jul-16  2016  Unprovoked    Alicante Province
# 34    Reported 08-Jul-2016  2016  Unprovoked       Canary Islands
# 104              25-Dec-15  2015  Unprovoked  Grand Canary Island
# 159              18-Aug-15  2015     Invalid             Alicante
# 249   Reported 03-Dec-2014  2014    Provoked              Granada
# 282                 Sep-14  2014  Unprovoked            Catalonia
# 287              27-Aug-14  2014  Unprovoked             Alicante
# 307              20-Jul-14  2014  Unprovoked       Canary Islands
# 434              07-Jul-13  2013     Invalid            Catalonia
# 788              16-Jul-10  2010    Provoked  Grand Canary Island
# 884              24-Jul-09  2009     Invalid            Catalunya
# 1234             13-Jul-06  2006     Invalid             Alicante
# 2251             03-Sep-93  1993  Unprovoked         Costa Blanca
# ...

# %%
paises=[]
for p in df['Country']:
    paises.append(p)
print(set(paises))
# Out:
# {nan, 'IRAN / IRAQ', 'NORTHERN MARIANA ISLANDS', 'BRITISH VIRGIN ISLANDS', 'PACIFIC OCEAN ', 'IRAQ', 'KUWAIT', 'USA', 'EGYPT / ISRAEL', 'ENGLAND', 'SOUTH PACIFIC OCEAN', 'RED SEA?', 'BELIZE', 'ANGOLA', 'PANAMA', 'PERSIAN GULF', 'ITALY / CROATIA', 'INDIAN OCEAN', 'LIBYA', 'HONDURAS', 'JOHNSTON ISLAND', 'TUVALU', 'TRINIDAD & TOBAGO', 'CUBA', 'VANUATU', 'BARBADOS', 'PACIFIC OCEAN', 'NEW ZEALAND', 'COSTA RICA', 'LIBERIA', 'CYPRUS', 'KOREA', 'INDIAN OCEAN?', 'NICARAGUA ', 'UNITED ARAB EMIRATES (UAE)', 'GEORGIA', 'COOK ISLANDS', 'FRENCH POLYNESIA', 'REUNION', 'SUDAN?', 'EQUATORIAL GUINEA / CAMEROON', ' PHILIPPINES', 'VIETNAM', 'MEXICO ', 'NETHERLANDS ANTILLES', 'CAPE VERDE', 'NORTH ATLANTIC OCEAN ', 'PALAU', 'MARTINIQUE', 'SOUTH CHINA SEA', 'SENEGAL', 'MALDIVE ISLANDS', 'SAMOA', 'SCOTLAND', 'EL SALVADOR', 'ALGERIA', 'KIRIBATI', 'NAMIBIA', 'FALKLAND ISLANDS', 'BRAZIL', 'SPAIN', 'NORTHERN ARABIAN SEA', 'ST. MAARTIN', 'St Helena', 'CEYLON (SRI LANKA)', 'MOZAMBIQUE', 'PHILIPPINES', 'GREECE', '
# ...

# %%
spain_df2_2000 = spain_df2[(df['Year']>1999)]
# Out:
# /home/eduardo/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
spain_df2_2000
# Out:
#                       Date  Year        Type                 Area  \
# 20               29-Jul-16  2016  Unprovoked    Alicante Province
# 34    Reported 08-Jul-2016  2016  Unprovoked       Canary Islands
# 104              25-Dec-15  2015  Unprovoked  Grand Canary Island
# 159              18-Aug-15  2015     Invalid             Alicante
# 249   Reported 03-Dec-2014  2014    Provoked              Granada
# 282                 Sep-14  2014  Unprovoked            Catalonia
# 287              27-Aug-14  2014  Unprovoked             Alicante
# 307              20-Jul-14  2014  Unprovoked       Canary Islands
# 434              07-Jul-13  2013     Invalid            Catalonia
# 788              16-Jul-10  2010    Provoked  Grand Canary Island
# 884              24-Jul-09  2009     Invalid            Catalunya
# 1234             13-Jul-06  2006     Invalid             Alicante
#
#                           Activity  Age  \
# 20                        Swimming   40
# ...

# %%
df["Sex"].value_counts()
# Out:
# M      4835
# F       585
# M         2
# .         1
# lli       1
# N         1
# Name: Sex, dtype: int64

# %%
df["Activity"].value_counts()
# Out:
# Surfing                                                                                                      904
# Swimming                                                                                                     819
# Fishing                                                                                                      414
# Spearfishing                                                                                                 321
# Bathing                                                                                                      153
# Wading                                                                                                       144
# Diving                                                                                                       123
# Standing                                                                                                      97
# ...

# %%
df["Fatal (Y/N)"].value_counts()
# Out:
# N          4315
# Y          1552
# UNKNOWN      94
#  N            8
# n             1
# F             1
# #VALUE!       1
# N             1
# Name: Fatal (Y/N), dtype: int64

# %%
spain_df2["Area"].value_counts()
# Out:
# Canary Islands         7
# Catalonia              4
# Alicante               3
# Cádiz                  3
# Malaga                 2
# Grand Canary Island    2
# Valencia               2
# Eastern Catalona       1
# Sants-Montjic          1
# Alicante Province      1
# Valencia               1
# Galica                 1
# Gran Canaria           1
# Málaga                 1
# Costa Blanca           1
# Andalucia              1
# Balearics              1
# Galicia                1
# Catalunya              1
# Granada                1
# Name: Area, dtype: int64

# %%
spain_df2["Activity"].value_counts()
# Out:
# Swimming                                    12
# Fishing                                      4
# Bathing                                      4
# Diving                                       2
# Wading                                       2
# Skin diving                                  2
# Spearfishing                                 1
# Dangling feet in the water                   1
# Fell into the water                          1
# Fishing                                      1
# Fell overboard from P&O steamship Arabia     1
# Playing with an air mattress                 1
# Fishing for blue sharks                      1
# Swimming alongside the SS Kearsarge          1
# Windsurfing                                  1
# Name: Activity, dtype: int64

# %%
spain_df2["Injury"].value_counts()
# Out:
# FATAL                                                                                                          8
# Survived                                                                                                       2
# Lacerations to right hand                                                                                      2
# Minor injury                                                                                                   2
# Feet severed                                                                                                   1
# Lacerations to left forearm                                                                                    1
# Leg bitten                                                                                                     1
# Abrasions                                                                                                      1
# ...

# %%
df["Time"].value_counts()
# Out:
# Afternoon                 174
# 11h00                     123
# Morning                   107
# 12h00                     107
# 15h00                     100
# 16h00                      94
# 14h00                      93
# 16h30                      72
# 13h00                      71
# 14h30                      70
# 17h30                      69
# 17h00                      64
# 18h00                      62
# 15h30                      62
# 11h30                      60
# Night                      58
# 13h30                      56
# 10h00                      53
# 09h00                      46
# 10h30                      45
# 12h30                      33
# Evening                    33
# Late afternoon             32
# 07h30                      30
# 09h30                      30
# 08h00                      28
# 18h30                      27
# 08h30                      25
# 19h00                      23
# 07h00                      20
#                          ...
# ...

# %%
null_cols = df.isnull().sum()
null_cols
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64
