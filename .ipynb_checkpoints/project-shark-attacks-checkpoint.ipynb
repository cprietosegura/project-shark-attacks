# %%
import pandas as pd

# %%
df = pd.read_csv("../project-shark-attacks/Input/GSAF5.csv")

# %%
df.head(5)
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# 0        NaN  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# 1        NaN  Orlando Sentinel, 9/19/2016   2016.09.18.b-Luciano.pdf
# 2        NaN  Orlando Sentinel, 9/19/2016       2016.09.18.a-NSB.pdf
# 3        NaN           The Age, 9/18/2016  2016.09.17-Angiolella.pdf
# 4  2 m shark           The Age, 9/16/2016  2016.09.16-BellsBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0  2016.09.18.c           5993         NaN         NaN
# 1  2016.09.18.b           5992         NaN         NaN
# 2  2016.09.18.a           5991         NaN         NaN
# 3    2016.09.17           5990         NaN         NaN
# 4    2016.09.15           5989         NaN         NaN
#
# [5 rows x 24 columns]

# %%
print(df.columns)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df = df.rename(columns={"Sex ": "Sex"})
df = df.rename(columns={"Species ": "Species"})

# %%
#selecciono las columnas que me interesan para estudiar cómo ha afectado la moda del surf en los ataques de tiburones.
df=df[['Case Number','Year','Country','Activity']]
df.head(20)
# Out:
#      Case Number  Year        Country           Activity
# 0   2016.09.18.c  2016            USA            Surfing
# 1   2016.09.18.b  2016            USA            Surfing
# 2   2016.09.18.a  2016            USA            Surfing
# 3     2016.09.17  2016      AUSTRALIA            Surfing
# 4     2016.09.15  2016      AUSTRALIA            Surfing
# 5   2016.09.15.R  2016      AUSTRALIA            Fishing
# 6     2016.09.11  2016            USA             Wading
# 7     2016.09.07  2016            USA           Swimming
# 8     2016.09.06  2016  NEW CALEDONIA       Kite surfing
# 9   2016.09.05.b  2016            USA    Boogie boarding
# 10  2016.09.05.a  2016      AUSTRALIA            Surfing
# 11    2016.09.04  2016            USA      Body boarding
# 12    2016.09.01  2016            USA       Spearfishing
# 13  2016.08.29.b  2016            USA            Surfing
# 14  2016.08.29.a  2016            USA            Surfing
# 15    2016.08.27  2016        REUNION            Surfing
# 16    2016.08.25  2016            USA             Wading
# 17    2016.08.07  2016        BAHAMAS         Snorkeling
# 18    2016.08.06  2016            USA  SUP Foil boarding
# 19    2016.08.04  2016            USA            Surfing

# %%
df=df.rename(columns={'Case Number':'Case Id'})

# %%
df.shape
# Out:
# (5992, 4)

# %%
#elimino filas duplicadas
df.drop_duplicates(subset ="Case Id", keep = False, inplace = True)

# %%
df.shape
# Out:
# (5960, 4)

# %%
print(df.dtypes)
# Out:
# Case Id     object
# Year         int64
# Country     object
# Activity    object
# dtype: object

# %%
surf_df = df[(df['Activity']=='Surfing')]

# %%
surf_df.shape
# Out:
# (898, 4)

# %%
#con esta formula me puede interesar para ver cuantos casos de surfing antes y después de 1960, 
#época de la popularización del surf
spain_df2_2000 = spain_df2[(df['Year']>1999)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d05bba879bcb> in <module>
#       1 #con esta formula me puede interesar para ver cuantos casos de surfing antes y después de 1960,
#       2 #época de la popularización del surf
# ----> 3 spain_df2_2000 = spain_df2[(df['Year']>1999)]
#
# NameError: name 'spain_df2' is not defined

# %%
df["Activity"].value_counts().head(30)
# Out:
# Surfing            898
# Swimming           818
# Fishing            411
# Spearfishing       319
# Bathing            153
# Wading             141
# Diving             123
# Standing            97
# Snorkeling          76
# Scuba diving        73
# Body boarding       54
# Body surfing        48
# Swimming            47
# Pearl diving        32
# Treading water      32
# Kayaking            28
# Free diving         26
# Boogie boarding     26
# Fell overboard      21
# Windsurfing         18
# Boogie Boarding     16
# Walking             15
# Shark fishing       15
# Surf skiing         12
# Canoeing            12
# Fishing             12
# Rowing              12
# Floating            12
# Surf-skiing         12
# Surf fishing        11
# Name: Activity, dtype: int64

# %%
#compruebo el número de valores nulos por columna
null_cols = df.isnull().sum()
null_cols
# Out:
# Case Id       0
# Year          0
# Country      43
# Activity    522
# dtype: int64

# %%
#le doy un valor a los nulos de la columna país porque me interesa más la actividad que el país
df["Country"].fillna("Unknown", inplace = True)

# %%
#elimino los nulos
df=df.dropna()

# %%
df.shape
# Out:
# (5438, 4)

# %%
set(df["Activity"])
# Out:
# {'Spearfishing ',
#  'Spearfishing or fishing',
#  'Diving for trepang',
#  'In deep water about 100 yards from his ship',
#  'Esso Bolivar was torpedoed & shelled by the German submarine U-126',
#  'Photographing fish',
#  'Surf-skiing',
#  'Playing in knee-deep water',
#  "Diving to untangle a crab trap line from boat's propeller",
#  'Motor boat Rebel Belle lost',
#  'Swimming, towing the shark',
#  'Shark fishing, knocked overboard',
#  'Free diving & spearfishing',
#  'Dismantling cable buoys of the cable ship All America',
#  'boat capsized',
#  'Touching sharks',
#  'Boogie boarding / wading',
#  'Freedom swimming',
#  'Tandem surfing',
#  'Swimming, after boat swamped',
#  'Diving for trochus',
#  'Body surfing, stood up on sandbar',
#  'Fleet of canoes caught by a squall and charged by sharks.',
#  'Net fishing',
#  'Small boat swamped, 4  people swimming to shore but he fell behind the other 3 and vanished',
#  'Grabbed shark & threw it on deck',
#  'HMAS Parramatta torpedoed & sunk by the U-559',
#  'Suicide',
#  'Swimming, naked',
#  'Ferry boat sank',
#  'Sittting in water with his child',
#  'Fishing / washing bait off hands',
#  'Removing fish from a trap',
#  'Free diving, surveying a pipeline & examing cathodes under jetty',
#  'Floating or standing',
#  'Swimming in section of river used for washing clothes & cooking utensils',
#  'Floating on back',
#  "Fishing from 32' boat",
#  'Surfing or body surfing',
#  'The 6015-ton British ship Empire Avocet was torpedoed by the German submarine U-125. ',
#  "During a shark fishing tournament, the 18' Boatem was capsized by waves, throwing 3 men into the water ",
#  'Dropping anchor',
#  'Sea disaster : Wreck of the Taiaroa',
#  'Bringing hooked, harpooned shark onboard boat',
#  'ship William Penn grounded & broke apart',
#  'Hauling in net with shark in it',
#  'Skindiving,',
#  'Swimming to retrieve a flannel',
#  'Adrift after wave swamped engine',
#  '2 messboys (Jeppsen) & Tony Latona (13) were playing on the afterdeck of the Danish ship Grete Maersk. Jeppsen fell overboard, Latona threw a lifebelt then jumped in to help him. Ship didn’t notice they were missing',
#  'Diving?',
#  'A dhow capsized',
#  'Free diving, carrying speargun',
#  'Surfing, paddling seawards',
#  'Fishing in Alabama Deep Fishing Rodeo',
#  'Fishing (trolling)',
#  'Swimming, poaching perlemoen',
#  'Sitting',
#  'Shark tagging',
#  'Dynamiting fish',
#  'Reached out to disentangle rope & fell overboard',
#  'Swimming crawl stroke',
#  'Fishing, shark caught in his net',
#  'Fishing from surfski',
#  'The boat Caribou II sank',
#  'Underwater photography',
#  'Sitting on surfboard',
#  'Fell overboard & swimming',
#  'Anti-Aircraft cruiser USS Atlanta (CL,-05) travelling in convoy after the Battle of Midway, encountered a Japanese flotilla  (Battle of Guadalcanal) &, heavily damaged by gunfire, she was lost off Lunga Point. Victim was swimming when bitten.',
#  'Swept out to sea by the tsunami, she clung  to a log for 24 hours',
#  'Attacked shark with fists',
#  'S.S. Marine Sulphur Queen, laden with molten sulphur was bound from Beaumont, Texas for Norfolk, VA, when she disappeared with 39 on board',
#  'Swimming from makeshift raft  to life vest after fishing boat sank',
#  "Lying prone in 2' of water",
#  'Fishing with a cast net',
#  'Walking out of the water after surfing',
#  'Free diving / Spearfishing',
#  'Removing shark from tank in nightclub ',
#  'Fishing, setting nets',
#  'Free diving for trochus',
#  'Feeding a shark',
#  'Shark fishing',
#  "Overcome by CO fumes, fell overboard from 36' fishing cruiser & prop slashed arm",
#  'Cleaning a tank',
#  'Boat capsized, swimming ashore',
#  'Spearfishing, but standing in the water',
#  'Spearfishing on Scuba',
#  'Boating',
#  'Swimming to mail boat',
#  'Playing ',
#  "Competing in U/W endurance record, standing beside drum in 10' of water",
#  'Among 31 survivors of crew from the sampan Fukulya Maru (which reached Thursday Island in rowing boat) was a man whose arm had been bitten off by shark. The sampan wrecked west of McArthur island ',
#  'Treading water/ Surfing',
#  'Jumped overboard while intoxicated',
#  'Scuba diving (ascending using scooter)',
#  'Crabbing (spearing crabs)',
#  'Foundering of the Israeli freighter Mezada',
#  'Taking wife to beach & about 1 m from the shore',
#  'Swimming from shore to anchored sailboat',
#  'Free-diving',
#  'Swimming outside the safety enclosure attempting to retrieve a tennis ball drifting toward midstream ',
#  'Fishing, on a boat',
#  'Thrown from destroyer when shell hit',
#  'Went over side of boat at trochus ground',
#  'Kayaking',
#  'Scuba Diving for scallops',
#  'Dived overboard & was swimming near stern of trawler',
#  'On inflatable raft',
#  "Holding shark's tail ",
#  'Free diving / Spearfishingat edge of reef',
#  'Paddling',
#  'Fishing (illegally)',
#  'The inter-island ferry Vula sank in heavy weather',
#  'Removing shark from net',
#  'Swimming on surface',
#  'Wreck of the USS Somers',
#  'The steamship Bonnie Dundee lost in collision',
#  "Fell off surfboard 20' from shore",
#  'Swimming to shore from capsized kayak',
#  'Fishing, wading with string of fish',
#  'Scuba diving & U/W photography',
#  'Wreck of the steamship Sultan of Bombay',
#  'native boats sunk in storm',
#  'Paddleskiing',
#  'Swimming back from anchored sailboat',
#  'Fishing from shore',
#  'C47 aircraft carrying 5,000 lbs of ice ditched in the sea',
#  'Explosion & sinking of the USS Juneau after being torpedoed by the submarine  I-85',
#  'Body surfing & treading water',
#  'Swimming in fish tank',
#  'The passenger ship Pioneer Cebu  capsized & sank in Typhoon Irma',
#  'Spearfishing & lassoed shark',
#  'Shipwrecked; adrift on raft for 2 days & 2 nights',
#  'Air Disaster',
#  'Clinging to shipwrecked junk',
#  'Spearfishing, carrying his catch',
#  'Swimming, using bundles of sticks as raft',
#  'Swimming /  Whale Watching',
#  'Dived overboard to retrieve dinghy',
#  'Fishing for white sharks',
#  'Launching rowboat through the surf',
#  'Spear fishing, removing fish from spear',
#  'Fishing for yellowtail, Seriola quinqueradiata',
#  'Rowing',
#  "Sinking of the 40' Esperanza off St. Maartin with 36 refugees on board",
#  'Removing hook from shark',
#  'On 6-Nov-1942, the German submarine U-68 sank the City of Cairo 5 days from Cape Town, survivors took to lifeboats & rafts. On the 15th day, a fireman jumped over the stern & was taken by sharks',
#  'Diving for trochus , but swimming on surface',
#  'Competing in the Woodvale Atlantic Rowing Race',
#  'Walking on reef',
#  'Swimming out to rescue swimmers in difficulty',
#  'Water-skiing',
#  'Fell overboard?',
#  'Fishing, holding fish in his left hand',
#  'Fishing for sharks',
#  'Canoe swamped',
#  'Reviving a sedated shark',
#  'Kneeling in the water',
#  'Washed off freighter Huncliff by a freak wave',
#  'On life raft tethered to lifeboat. A seaman put hand over side to rinse a cup',
#  "Sitting in 3' of water",
#  'Fishing, hauling in a 5-lb snapper',
#  'Free diving , but surfacing',
#  'Fell onto dead shark',
#  'Free diving for molluscs',
#  'Swimming behind sailboat',
#  'Lost his footing & fell overboard',
#  'Floating near boat & observing bioluminesce',
#  'Two canoes with 14 aboard blown to sea in a storm. While adrift for 3 week, one person fell overboard and was killed by a shark',
#  'Canoe capsized by shark',
#  'Diving for pearl shell',
#  '90 European civilians, many women & children, were placed on the deck of a Japanese submarine that submerged when it was well offshore',
#  'Wading',
#  'Fell into the water',
#  'Sea Disaster, sinking of the  SS Vestris',
#  'Adrift after ditching plane in the sea',
#  'Tech diving ',
#  'Fishing (big game)',
#  'Washing',
#  'Fell overboard ',
#  'Boeing 757 enroute from Porta Plata plunged into the sea',
#  'Boat capsized',
#  'Hookah diving for sea urchins',
#  'Boat stopped to repair electric pump',
#  'Spearfishing using scuba',
#  'Jerked overboard while pole fishing for tuna',
#  'Canoe with 3 men onboard sank',
#  'Wreck of the Union Steamship Company 982-ton iron steamer Kafir',
#  'Body Boarding',
#  'Fell off aircraft carrier',
#  'Surfing / Wading',
#  'Fishing boat swamped in a storm',
#  'Fishing,  tarpon being chased by shark  leapt across his skiff, breaking it in half & Larkin became tangled in the net',
#  'The schooner Tahitienne foundered in a hurricane',
#  'Fishing, tossing netted shark onboard',
#  'Swimming to shore from capsized sailboat',
#  "Accidentally stood on hooked shark's tail before attempting to gut it ",
#  'Watching seals',
#  'Aircraft crashed into sea',
#  'Playing / standing',
#  'Anti-sabotage night dive exercise alongside destroyer (Scuba diving)',
#  'The 2379-ton French steamer La Seyne collied with British steamer Onda & sank in minutes. Passengers jumped overboard expecting to be picked up by Onda’s boats',
#  'Yacht of Michael Howell capsized',
#  'Pearl diving, but standing in the water',
#  'Motor launch Baby Princesa capsized with 22 people on board',
#  'Overturned skiff',
#  'Japanese POW ship Arisan Maru with 1800 American prisoners of war on board bound for slave labor camps was torpedoed by an American submarine',
#  '43-ton schooner Irene capsized & sank',
#  'Adrift on refugee raft',
#  'Jumped overboard from torpedoed Panamanian freighter',
#  "Spearfishing, holding 5' speared fish",
#  'Washed overboard from the barque Mary Eady',
#  'Murdered by Thai pirates',
#  'Sea Disaster',
#  'Dress diving',
#  'Spearfishing on scuba & transferring fish onto a stringer',
#  'Surfing (or body boarding)',
#  '"Swimming vigorously"',
#  'Swimming, wearing black wetsuit & swim fins',
#  'Sea Disaster, sinking of the motorship Wingate',
#  'The World Liberty and the tanker Mosli collided. The  Halcyon Breeze sent a lifeboat to the rescue, but it was smashed, throwing 6 men in the  water.',
#  'Kite-Boarding',
#  'He drowned when boat capsized',
#  'Spearfishing, shot a turtle',
#  'Testing classified underwater electronic gear for Raytheon Corporation, vessel torn apart by explosion',
#  'Free diving for sinkers',
#  'Swimming ashore after launch capsized',
#  'Fishing, hauling in a set line',
#  "Skin diving. Grabbed shark's tail; shark turned & grabbed diver's ankle & began towing him to deep water",
#  'Fishing in ankle-deep water',
#  "Fishing, removing gaff from shark's mouth",
#  "Days before the surrender of Singapore, the 3 men escaped to Sumatra where they acquired a 17' dinghy. After 125 days at sea they drifted back to Sumatra",
#  'Windsurfing',
#  'Skindiving, fish at belt',
#  'Spearfishing / swimming on surface',
#  'Killing a shark',
#  'Boat of a Hawaiian brig was stove in by  whale',
#  'Surfing (sitting on his board)',
#  'Fishing schooner Jose Luis foundered',
#  'Air/Sea Disaster Pan-American Airlines Stratocruiser with 44 people onboard crashed into the sea',
#  'Paddling a surfboat',
#  'Swimming underwater from crayfish cage to a fishing bait',
#  'Freediving, inspecting Kaunakakai wharf construction after blasting & dredging ',
#  'Surf skiing',
#  'Fell from the jetty',
#  'Body boarding or surfing',
#  'Defecating in water beneath the docks',
#  '"Flying Tiger" transport plane went down with 5 men onboard',
#  'British ship, Britannia,  was loading lumber. He was bathing',
#  "Onboard 21' powerboat that capsized in rough seas",
#  'Columbian petrol barge Rio Atrato burned and sank',
#  'Inspecting teeth of supposedly dead (hooked & shot) shark',
#  'Walking in surf',
#  'Hunting turtle',
#  'boat from the Austrian ship Elizabeth',
#  'Diving for shells, saw shark circling wife near the surface, intercepted shark & it pulled him beneath the water',
#  'Feeding fish',
#  'Fishing for bottom fish',
#  'Lifesaving drill',
#  'Fishing from dinghy',
#  'Sea disaster',
#  'Sea Disaster Sinking of ferryboat Christina',
#  'Wreck of the 150-ton brig Maria',
#  'Attempting to retreive a dinghy',
#  'Diving, recovering fish killed by dynamite',
#  "Zosimo & his son, Jeffrey Popa, failed to return from overnight fishing trip in a 14' boat, Boat apparently sank, debris recovered but his son & boat were never found",
#  'Diving for trochus shell',
#  'Wreck of  large double sailing canoe',
#  'Rescuing',
#  'Adrift on raft after their ship was sunk by an Axis raider ',
#  'Diving, but on the surface when bitten by the shark',
#  'Fell into water while attempting to boat a swordfish',
#  'Swimming breast stoke',
#  "Adrift on a 4'  raft for 32 days",
#  'Wading (shrimping)',
#  'Shark Fishing',
#  'Had just dived into water & was swimming',
#  'Washing horses',
#  'The steamships Thingvalla and Geiser collided',
#  'Swimming to shore from boat or kayak',
#  'Washed overboard into school of fish',
#  'Body surfing / treading water',
#  'Free diving, collecting sand dollars',
#  'Crayfishing',
#  'Chumming for sharks',
#  'Fly fishing',
#  'Jumped off surfboard & landed on the shark',
#  'Fishingat',
#  'Standing in inner tube',
#  'Spearfishing, carrying fish on spear',
#  'Ship Mariston torpedoed & sunk',
#  'Canoe swamped, swimming back to canoe',
#  'Fishing / cleaning fish, dived into water to retrieve a lost fish',
#  'Diving for sponges',
#  'Swimming from the New Venture ',
#  'Searching for remains of  Dr. Marais',
#  'Swimming / treading water',
#  'Finning the shark',
#  'Kite boarding',
#  "Diving in Sharkey's Reef restaurant’s aquarium",
#  'Fishing for albacore',
#  'Sailboarding, fell into water 100 yards outside the breakwater',
#  'Observing a shark feeding on a carcass of a humpback whale',
#  'Snorkeling (filming the sardine run)',
#  'Standing in water with child in her arms',
#  'Italian liner Principessa Mafalda sank',
#  'Playing volleyball with friends',
#  'The British steamer Caribbee foundered',
#  'Petting a shark',
#  'Swimming close to wharf',
#  'Boat swamped',
#  'Standing in waist-deep water',
#  'Lobstering',
#  'Diving in tuna net',
#  'Gaffing & attempting to bring onboard a harpooned shark',
#  'Feeding mullet to sharks',
#  'Crossing inlet in a boat, seen fighting sharks with his oar, sharks smashed boat',
#  'Splashing in surf',
#  'Swimming after falling overboard from the sealing ship Vesper',
#  'ship torpedoed 400 miles off the African coas. Man was clinging to hatch cover',
#  'Surfing on "chest board" (boogie board?)',
#  'Fell overboard  from the Taiwanese fishing trawler Lien Cheng Feu ',
#  'Conducting research',
#  'Hookah diving for abalone (descending)',
#  'Wreck of the 1308-ton Norwegian ship Auckland',
#  'Fell off banana boat',
#  'Floating with life preserver after his boat foundered',
#  'Hunting seashells',
#  'Aircraft ditched in the sea, swimming ashore',
#  'Hookah diving (submerged)',
#  'Free diving & spearfishing ',
#  'Dangling feet in the water',
#  'Swimming to shore after boat capsized by a squall',
#  'Moving shark from tuna vessel when boat rolled, placing both man & shark in chest-deep water',
#  'Longline fishing for sharks',
#  'Swimming underneath house on pilings',
#  'Wreck of the tug Magellan',
#  'Fell overboard from USS Ward',
#  'Swimming between boats',
#  'Scuba diving at seal colony',
#  'Swimming, after single-engine aircraft went down in the sea',
#  'Paddling a canoe',
#  'Free diving for abalone (surfacing)',
#  'boat from City of Naples capsized',
#  'Hauling in net',
#  'Catching crabs',
#  '13 men in the water after sailboat capsized & sank',
#  'Swimming or surfing',
#  'Fleeing across a river',
#  'Free diving Spearfishing',
#  'National Airlines DC7B enroute from Miami to Los Angeles with 42 or 46 people on board went down in heavy fog',
#  'Air/Sea Disaster involving C-54 Air Force Transport No. 2686 with 37 on board',
#  'Splashing in water ',
#  "Fishing - 'tag & release'",
#  'Free diving / spearfishing',
#  'Commercial diver (submerged or treading water)',
#  'Diving (shell maintenance)',
#  'Attempting to ride a shark',
#  'Fishing for trout ',
#  'Spearfishing / Free diving',
#  'Spearfishing, but swimming on surface',
#  'Cleaning the side of a ship',
#  'Surfing, paddling shorewards',
#  'Fishing, had just speared a ulua',
#  'Washing sand off a speared fish',
#  'Dutch merchant ship Zaandam torpedoed  by the U-174 amidships, sank & dozens of survivors took to rafts & boats. One man, Izzi, who drifted 83 days on a raft related that sharks attacked many men in the water when the ship went down',
#  'Shrimping',
#  'Clinging to overturned rowing boat',
#  'Attempting to drive shark from area',
#  'Playing in the water',
#  "Fishing, caught a 15' shark & took it onboard",
#  'Fishing (Seining)',
#  'Playing in the surf',
#  'Fishing, hooked shark towed boat out to sea, storm swamped boat',
#  'Treading water, waiting for a wave',
#  'Scuba Diving for lobster (at surface)',
#  'Jumped out of canoe',
#  'Fishing for whiting',
#  'B-24 aircraft crashed  into the sea',
#  'Small vessel with 13 men on board capsized crossing the bar and 6 men drowned.  The 7 survivors were swimming to shore',
#  'Kite Surfing',
#  'The troopship Britannia was sunk by the German raider Thor',
#  'Net fishing, fell into the water',
#  "Ship's boat capsized in squall, captain & 2 sailors clinging onto hull",
#  'Swimming with goggles',
#  'The 6711-ton American freighter & troop transport Cape San Juan was torpedoed by the Japanese submarine I-21',
#  'Boarding a ship',
#  'The shrimper Loless Maurine capsized in heavy seas & the men were swimming ashore  ',
#  'Dived from dinghy to retrieve oar in heavy seas',
#  'Fishing for yellowtail',
#  'Body surfing or body boarding',
#  'Exercising his dog in the shallows',
#  'Crew swimming alongside their anchored ship',
#  'Jumped overboard after murdering 2 shipmates',
#  'Feeling the shark’s teeth',
#  'Body boarding',
#  'Spearfishing (Free diving)',
#  'Swimming to canoe',
#  '3,909-ton Panamanian freighter Chieh Lee sank in a typhoon',
#  'Photographing sharks underwater using Scuba',
#  'Swimming alongside yacht Mexico Fiesta',
#  'Steinhart Aquarium',
#  'Helmet diving in Miami Seaquarium',
#  'Kayak fishing',
#  'Steamer Una wrecked with 75 laborers onboard. Survivors took to rafts & lifeboats.',
#  'Wading near a fishing net',
#  'Spearfishing / free diving',
#  'pêcheur de bichiques',
#  'The 168-ton Belmore foundered in heavy seas',
#  'Diving for pearls',
#  'Resting on surfboard',
#  'Fishing for basking sharks',
#  'Spearfishing & diving for paua',
#  'Investigating shark sighting',
#  'Picking up shark by the tail',
#  'Fishing, two large sharks passed. He speared one and it bit him',
#  'Lifeboat capsized',
#  'Measuring sharks',
#  'Fishing for kob',
#  'Adrift on life raft',
#  'Swimming after a tennis ball',
#  'Ditched aircraft, 3 men in the water. Swam for 31 hours',
#  'Free diving / spearfishing, from paddleboard & floating on the surface',
#  'Fishing for squid aboard the trawler Shikishima-Maru when the shark leapt into the boat',
#  'Collecting fish in military trap when bitten by captured shark that had been shot by soldiers with Garten',
#  'Diving. Shark “swallowed’ his hand, so he threw his other around the shark and went “shark-back riding” for 30 yards until the shark opened its jaws',
#  'Dragging stranded shark ashore',
#  'Spear fishing',
#  'Free diving for trochus ',
#  'Swimming beside launch',
#  'Scuba diving, hand feeding sharks',
#  'His ship, the US destroyer Duncan DD 485, had been  sunk by crossfire from Japanese warships. He was wearing a kapok lifejacket & using 2 aluminum powder tins for floatation  ',
#  'Sea disaster, foundering of the cargo vessle M/V Dorolonda',
#  'Wading or swimming',
#  'Hookah diving for pen shells ',
#  'Skin diving',
#  'Swimming (recovering remains of Stilwell) ',
#  'Fishing for prawns',
#  'Surfing, but lying prone on his board',
#  'Collecting crayfish',
#  'Portuguese Airliner with 9 people aboard went down. ',
#  'Swimming / floating',
#  'He was fighting a shark when his boat capsized & he disappeared',
#  'Bathing with her mother',
#  'Diving & force-feeding the shark',
#  'Coming ashore on a hawser',
#  'Unknown, their unoccupied yawlboat was recovered',
#  'Attempting to drive shark away from the beach',
#  'Diving off jetty',
#  'On expedition filming a feature movie & standing on tripod',
#  'Cruising',
#  'Bathing in water 0.9 m deep',
#  'When  a deckhand  jumped overboard, McIver dived after him with a rescue line.',
#  'Fishing from paddleski',
#  'Attempting to remove fishing net from submerged object',
#  'Their 9 m launch was run down by a 25,000-ton Japanese freighter  on the night of 3-11-1977 & they drifted, clinging to an icebox for 2 days',
#  'Parachuted into Pacific',
#  'Traveling by boat',
#  'Swimming ashore from capsized boat',
#  'Swimming / Wading',
#  'Killing  sharks',
#  'Pearl diving from lugger Whyalla',
#  'Helping men land a shark',
#  'In waist-deep water',
#  'Scuba diving ',
#  'Lashing logs together when he fell into the water',
#  "Filming 5' blue shark",
#  'Scuba diving for abalone (at surface)',
#  'Swimming, when caught in heavy seas',
#  'Netting shrimp',
#  'Fell overboard from steamship Rio Grande',
#  'Swimming / shipwreck',
#  'Spearfishing (but treading water on the surface)',
#  'Fishing, speared shark upset canoe & man fell in water',
#  'Standing, collecting bananas',
#  'Swimming alongside the schooner Catherine Wilcox',
#  'Playing on rock, slipped & fell into the water',
#  'Hardhat diving',
#  'Scurfing (surfboard being  towed behind a boat)',
#  'American minesweeper USS YMS-472 foundered in a typhoon - swimming to shore',
#  'Hand feeding sharks',
#  'Surfing, but standing in water alongside board',
#  'Survived crash of two-engine  C-46 transport plane carrying 62 migrant workers from Puerto Rico to USA ',
#  'Swimming / jumping off a jetty',
#  '4 men were bathing',
#  'Wading in school of baitfish',
#  'Spearfishing',
#  'Scallop diving on hookah',
#  'Accidentally dragged overboard from the sampan Holokahana into school of yellowfin tuna',
#  'Scuba diving / culling lionfish',
#  'Filming & feeding captive sharks',
#  'Fishing for octopus',
#  'Resting on body board',
#  'Capsized fishing boat',
#  'Freediving for abalone (at surface)',
#  'Surfing (lying prone on his board)',
#  'Diving for coins tossed from passenger ship',
#  'Surf bathing',
#  'Standing / Bathing',
#  'Skin diving for trepang but at surface next to the boat',
#  'S.S. Ramos foundered in a hurricane. Captain & 14 crew in water-logged lifeboats. ',
#  'Swimming in hip-deep water',
#  'Reported swept away by waves while gathering opihi',
#  'Standing in chest-deep water',
#  'Bathing close inshore',
#  'Snorkeling – hunting crayfish and abalone',
#  'Diving, feeding sharks',
#  'Air disaster: crash of Air France Super Constellation ',
#  '"Riding waves on a board"',
#  'Body surfing?',
#  'Scuba diving & spearfishing',
#  'Hunting crayfish ',
#  'S2N Navy scout plane went down, E.H. Almond & Lieut A.G. Reading in water',
#  'Dry shelling',
#  'B-24 crashed during a search mission. Survivors in raft for 47 days ',
#  'The 500-ton coastal trader Polurrian foundered ',
#  'Kayaking / Fishing',
#  "Bathing in 5' of water",
#  'Fishing from launch, fell into net with shark',
#  'Diving for lobsters',
#  'The MV Dona Marilyn sank in Typhoon Unsang with the loss of 389 lives',
#  'Surf skiing ',
#  'Fishing / diving',
#  'Fishing for rock lobster',
#  'Sitting in shallows',
#  'S2F-1 airplane crashed immediately after carrier take-off',
#  'Body surfing',
#  'ship M.V. Rizal sank during typhoon',
#  'Standing on ship deck',
#  "Bathing in 3' to 4' of water",
#  'Swimming with speared fish',
#  'Fell overboard from fishing schooner Halycon',
#  'Paddling on surfboard or body board',
#  'Standing in knee-deep water',
#  'Collecting fish from net',
#  'Fishing & spearfishing',
#  'Washing cooking pans',
#  'Spearfishing, pulled shark’s tail',
#  'Swimming naked near a date palm where many dates fell into the water',
#  'Swimming alongside NOAA research vessel Discoverer',
#  'Fishing for snappers & cleaning mullet. Put mullet over side of boat to wash it',
#  'Snorkeling',
#  'Fishing, boat capsized',
#  'Scuba Diving',
#  'Standing ',
#  'Scuba diving & filming',
#  'Swimming near jetty',
#  'Fell oveboard from steamer Wanderer',
#  'Paddle Skiing',
#  'Freediving for seashells',
#  'Helping friend land hooked shark',
#  'Swimming & snorkeling',
#  'cargo ship Southern Isle sank at 04h00',
#  'Pacific Seafarer of US Navy',
#  'Swimming on sandbar adjacent to channel',
#  'Gathering shells',
#  'On boat, preparing to dive',
#  'Boat, with 42 passengers onboard, capsized in rough seas',
#  'Surfing, fell off surfboard & stepped on the shark.',
#  'Paddling & sailing from Buenos Aires to Miami',
#  'Swimming, after sailboat capsized',
#  'Scuba diving in aquarium tank',
#  'Parachuted from balloon',
#  'Scuba diving for lobsters',
#  'Fishing for sharks when he became entangled in net & fell overboard',
#  'Murder',
#  'Touching the mouth of a supposedly dead shark',
#  'Riding floatation device',
#  'Wading, when he stepped on the shark',
#  "Adrift, hanging onto cushion, after his 17' skiff ran out of gas & capsized 3 miles from shore",
#  'Tuna fishing, standing on stern platform that was submerged by waves',
#  'Swimming or boogie boarding',
#  'Diving for pen shells',
#  'Playing / jumping',
#  'Boogie boarding or Surfing',
#  'Dived into sea from launch & bitten immediately',
#  'Swimming with mask & snorkel',
#  'Treading water after survivng crash of the US Navy airship K-74 that was hit by the German submarine U-134',
#  'Dived onto shark from floating stage',
#  'Diving for pearl',
#  'Ship lay at anchor & man was working on its rudder',
#  'Ferry boat Dona Paz with 4431 passengers exploded & caught fire when she collided with an  oil tanker ',
#  'Thrashing the water / imitating the shark victim from "Jaws"',
#  'Spearfishing, had fish on his spear',
#  'Taken as he dived into the water',
#  'Wade Fishing',
#  'Preparing to fish for jack-mackerel',
#  'Fishing for shrimp',
#  'Boogie-boarding / swimming',
#  'Commercial spearfishing',
#  'Dragging stranded shark into deeper water',
#  'Spearfishing using Scuba',
#  'Fishing ',
#  'Attempted to return injured shark to the sea',
#  'Free diving or wading back to shore',
#  'Examining netted shark, that had been shot',
#  'Swimming to shore from the Medic',
#  'Tagging sharks',
#  'Free diving but treading water at surface',
#  'Colombian  (Avianca) DC-4 airliner plunged into the sea 5 minutes after takeoff',
#  'Crossing the river mouth',
#  'Free diving with goggles',
#  'Returning to shore, collided with shark',
#  'Portuguese seaman fell overboard. Boat lowered to pick up with 1st mate & 4 crew, but done hurriedly & all were thrown into the water. As a second boat was lowered, a shark went after the 1st mate but he was rescued. Then the shark went after Mr. Andrews ',
#  'Surf paddling',
#  'Attempting to rescue drowning man',
#  'Scuba diving, attempting to catch a captive shark',
#  'Spearfishing, shot a sandtiger shark. Cord to spear tangled round his legs & a wave washed him onto a reef.',
#  'Wind surfing',
#  'Hooking into a whale',
#  'Standing on his hands',
#  'Fishing, sitting in stern of small boat, feet dangling in the water',
#  'Diving for sea urchins',
#  'Diving for beche-de-mer from lugger',
#  'Fell overboard from the Malacca',
#  'Swimming after harpooned whale capsized boat',
#  'Bathing',
#  'Boat exploded',
#  'Fishing boat',
#  'Playing in surf with his child  (9)',
#  'Cleaning fish',
#  'Ocean racing',
#  'Kayak Fishing',
#  'Standing alongside surfboard',
#  'Shark watching',
#  'Rowing an inflatable dinghy',
#  'Catching a turtle',
#  'A father bathing his smallest daughter when the shark bumped her out of his arms and carried her into deep water',
#  'Fishing boat capsized ',
#  'Fell overboard from a frigate & was swallowed by a shark. The captain fired a gun at the shark, and "the creature cast the man out of his throat."',
#  'Floating on a small orange raft ',
#  'Swimming or snorkeling',
#  'Angling',
#  'Netting menhaden, sharks caught in net',
#  'Dress diving, filming shark & pulling it through the water for a motion picture scene',
#  'Swimming from camp',
#  'Swimming / snorkeling',
#  'Attempting to rescue woman seized by shark',
#  'Hauling dead shark aboard, when another shark leapt out of the water & bit him',
#  'Dragging banana seeds through the shallows',
#  'SS Ethel Skakel foundered in Central America Hurricane of 1941',
#  'Put foot inside mouth of supposedly dead shark',
#  'Crabbing',
#  'Fishing in knee-deep water',
#  "40' fishing boat sank",
#  'The steamer Tahiti collided with the ferry Greycliffe',
#  'Hardhat diving ',
#  'Boogie boarding',
#  'Swimming / Body surfing',
#  'Collecting ornamental fish',
#  "Fell from his father's back into the water",
#  'Sinking of the ferryboat Bongbong 1',
#  "Fishing with hand net in 2' of water",
#  'Fishing for tunny',
#  'Windsurfing, but sitting on his board',
#  'Steamer Durao struck rock & filled, boats capsized, passengers & crew tried to swim to shore',
#  'The Pacquebot Laconia, enroute to Liverpool with 600 Italian prisoners onboard, was torpedoed by the German submarine  U-156 and only 2 rafts were launched before the ship went down. Unable to board an overcrowded raft, he was swimming.',
#  'Floating on air mattress',
#  'Swimming to avoid capture',
#  'Wade fishing',
#  'Bathing / standing',
#  'Surfing (pneumatic surfboard)',
#  'Attempting to rescue a shark',
#  'Helmet diving, collecting trochus shell',
#  'Fishing from prawn trawler',
#  'Swimming near shore',
#  'Boogie Boarding',
#  'Body surfing or Boogie boarding',
#  'Holding onto an inflatable boat',
#  'Boat capsized, clinging to line',
#  'Beach seine netting',
#  "Diving for trochus  from dinghy when seized by shark 6' below the surface",
#  'Floating with life buoy after pilot launch capsized',
#  'Attempting to catch a crocodile',
#  'Body found on deserted luxury yacht, 38’ Christine',
#  'NSB Meshing',
#  'In water with diving seabirds',
#  'Swimming between  anchored  pearling luggers',
#  'The Ward liner Esperanza stranded during a gale & she leapt overboard to rescue her dog which had been swept overboard.',
#  'Swimming & splashing',
#  'wreck of the State Oil Company ship Permina',
#  'Playing',
#  'Went to aid of child being menaced by the shark',
#  'Unknown',
#  'Net-fishing',
#  'Fishing, holding fish',
#  'Surfing, but swimming to his board',
#  'The 3540-ton Alfonso Penna was torpedoed & sunk by the Italian submarine Barbarigo',
#  'Ejected from F3H-2 aircraft ',
#  'Wading, fishing for flounder',
#  'No details',
#  'yachting accident',
#  'Boat capsized?',
#  'Surfing amid a shoal of sharks',
#  'Fishing for the shark that killed George Lundberg',
#  'Bathing with sister',
#  'Closed circuit diving (submerged). Diving to recover jettisoned packets of opium for police',
#  'Trailing the field in a surf race',
#  'Air Disaster - Piper aircraft crashed into the sea, killing all on board',
#  'Pulling anchor',
#  'Floating in inner tube',
#  'Swimming, towing a kayak',
#  'boat from ship Josephine capsized in squall',
#  'Washed into sea while picking opihi & attacked by 2 large sharks ',
#  'Fishing, one of three fishermen swept into the sea by a large wave ',
#  'Leaving the water',
#  'Standing, holding shark pup',
#  'Ditched plane in the sea & were adrift on a rubber life raft. ',
#  "Attempting to lasso shark's tail",
#  'Swimming with board',
#  'Removing shark from a trap',
#  'Harpooned shark',
#  'Fishing in shoulder-deep water',
#  'Dived into a school of baitfish',
#  'Hospital Ship Centaur torpedoed & sunk by the Japanese submarine I-177',
#  'small boat',
#  'Fell overboard while fishing for sharks',
#  'Night Surfing',
#  'Standing / fishing',
#  'Wading / fishing & carrying a bag of fish',
#  'The schooner Elizabeth, bound from Bluefields, Nicaragua to the river port of San Carlos foundered',
#  'Testing movie camera in full diving dress',
#  'Swimming after his canoe capsized',
#  'Conch diver',
#  'Chumming for white sharks',
#  'Walking in chest-deep water',
#  'Swimming to shore after a squall  capsized their motorized shark fishing boat',
#  'Setting crayfish pots',
#  'Free diving with a pod of dolphins',
#  'Swimming outside fishing net',
#  'Went overboard',
#  'Spearfishing & had just speared a ulua',
#  'Adrift after the sinking of the motor yacht Princess Dianne',
#  'Surfing, fell off surfboard',
#  'Fishing (rod & line)',
#  'Yacht race',
#  'The cutter Francis Adams foundered',
#  'A group of survivors on a raft for 17-days',
#  'Abandoning burning ship Captain George in raging seas',
#  'Crawling',
#  'Dog paddling or standing',
#  'British patrol boat 1250-ton HMS  Valerian foundered in a hurricane',
#  'Free diving',
#  'Wrangling a shark',
#  'Air disaster. Flash Airlines Boeing 737 crashed into the Red Sea',
#  'Diving for coins',
#  'Wading, netting fish',
#  'Diving from lugger',
#  'Swimming near life raft',
#  'Catching sharks under government contract',
#  '   ',
#  'Free diving / spearfishing (resting on the surface)',
#  'Spearfishing, dived to pick up a float line',
#  'Collecting aquarium specimens',
#  'Diving ',
#  'Free diving for abalone from Zodiac (submerged)',
#  'Clamming',
#  'Free diving / modeling',
#  'Climbing back on ship',
#  "Explosion destroyed 28' boat, survivors in the water ",
#  'Surf fishing / wading',
#  'Swimming / surfing',
#  'Pleasure boating',
#  'Fishing for bluefish',
#  'Washing a dog',
#  'Swimming near his boat',
#  'Royal Hawaiian skymaster DC-6B aircraft went down with  58 passenger & crew',
#  'Removing shark from a net',
#  'Wreck of the schooner Pohoiki ',
#  'Lobster fishing',
#  'Murdered',
#  'Fishing from dory, shark upset boat & he fell into the water',
#  'Competing in spearfishing championship & towing dead fish',
#  'Playing in the surf with his 2 dogs',
#  'A 210-ton brig was sunk by a Japanese submarine. Some of the survivors were machine-gunned & some were taken by sharks',
#  'Checking fish traps, fell into the water',
#  'Surfing with dolphins',
#  "Lying on the bottom of a 16' dinghy",
#  'Hurricane & Tidal Wave',
#  'Floating face down',
#  'Inebriated, woke from sleep and fell off deck into the water ',
#  'Hunting sharks',
#  'Lifesaving exhibition',
#  'Fell from cliff while fishing & disappeared in strong current',
#  'Swimming near canoe',
#  'SCUBA diving',
#  'Harpooning turtles',
#  'Spearfishing with Scuba gear',
#  'Shark fishing on the Don Agustín-VI. ',
#  'British ship Macedon was thrown on her beam ends by a sudden squall',
#  'Floating',
#  'Surfing on air mattress',
#  'Collecting fish ',
#  'A junk foundered',
#  'Jumping in swells',
#  'Collecting shells',
#  'Scooping prawns',
#  'Fishing, trying to catch the end of his fishing line',
#  'Jumped overboard and swimming',
#  'Wading?',
#  'HMS Victoria collided with the HMS Camperdown',
#  'Treading water',
#  'Swimming with boogie board',
#  'Bathing alongside ship',
#  '"Crossing the river"',
#  'Swimming, ducking for shells in water 0.9 m deep',
#  'Sitting on gunwale of boat',
#  'Fell or jumped overboard from the liner Rhynland',
#  'Jumped off rocks into white water',
#  'Spearfishing Competition',
#  'Dived into the water',
#  'Swimming, attacked at  surf carnival',
#  'Attempting to anesthetize shark',
#  'Riding horseback across the creek',
#  'Lobster diving using Scuba',
#  'Fishing from rocks, swept out to sea by large wave & treading water',
#  'Vehicle plunged over cliff into the water',
#  'Bathing in knee-deep water',
#  'Catching sardines',
#  'Diving for beche-de-mer',
#  'Swimming 10 m from shore',
#  'Retrieving meat from a cage in the water',
#  'Fishing, attempted to take a netted shark',
#  'Sitting on side of dinghy mending a net',
#  'British cruiser Dunedin torpedoed & sunk by the U-124',
#  'Feeding prawns to captive sharks',
#  'USS Hoel DD 533 sunk on 10/24/1944 in the Battle off Samar. 2 crewmen were swimmng alongside a floater net &',
#  'Commercial fishing vessel, Ev-nn, struck object & sank. Ken Crosby and  Jame & Ann Dumas adrift on makeshift raft.',
#  'Fishing for white shark',
#  'Petting captive sharks',
#  'Plane forced down, 3 men on rubber life raft. Put hand over side to feel drift of boat ',
#  'Fell overboard from P&O steamship Arabia',
#  'Dived from inner-tube',
#  'Walking',
#  'Boat Miss Becky  sank 12 miles from shore',
#  'Towing rubber dinghy',
#  'Wading to shore after surfing',
#  'Trailing hand in the water',
#  'Free diving for crayfish',
#  'Attempting to kill a shark with explosives',
#  'Dived overboard to check propeller of US Navy motor torpedo boat',
#  'Fishing trawler Flavio Gioia ',
#  'Swimming with fish attached to  belt',
#  'Fishing for red fish',
#  'Swimming from capsized pirogue',
#  'Spearfishing (free diving)',
#  'Attempting to swim across the Atlantic Ocean',
#  'Windsurfing (urinating on his board)',
#  'Diving / Filming',
#  'Sculling',
#  'Fishing from a kayak',
#  'Floating in tube',
#  'Transatlantic Rowing',
#  'Cleaning hull of ship ',
#  'Shipwrecked Persian Fleet',
#  'Cargo ship El Gamil entroute Suez to Yemen (Aden) when her cargo shifted and she sank. 19 Egyption sailors jumped into the water and swam for several hours before being bitten by sharks',
#  'Crouching in the water',
#  'Vessel caught fire & capsized, survivors in the water',
#  'Swimming near breakwater',
#  'Surf fishing in waist-deep water',
#  'Swimming at side of small boat',
#  'Diving / fishing',
#  'Fishing for pompano',
#  'Swimming. Passer-by, Len Bedford, heard him shriek , saw shark leap from the water & swimmer disappeared',
#  'Diving for sand dollars',
#  'Fishing for cod',
#  'Lying on surfboard & paddling',
#  'Swimming ashore from a "filibuster"',
#  'Sea Disaster, sinking of the fishing  launch Mavis',
#  'Swimming along a row of nets',
#  'Diving',
#  'Fishing (Drowned 2-Apr-2002)',
#  'Fishing, removing the shark from his line',
#  'Wreck / Technical diving',
#  'Pulling hooked salmon to boat',
#  'Japanese aircraft shot down. He was one of two survivors rescued by the U.S. destroyer Mugford',
#  'Pulling shark from the water',
#  'Gigging for flounder',
#  'Standing or boogie boardin',
#  'Treading for clams',
#  'Standing, collecting sea stars',
#  'On fishing boat & trailing hand in the water',
#  'Wakeboarding',
#  'Commercial Salvage Diving',
#  'Wade-fishing',
#  'Swimming / escaping imprisonment ',
#  'Shark fishing on the Ricardo Astorga',
#  'Bathing or body surfing ',
#  'Sunbathing on beach when he saw child being attacked by the shark',
#  'Hard hat diving',
#  'Surfing (or sailboarding)',
#  'Sinking of the ferryboat      Don Juan',
#  'Fell overboard from US Navy PC boat',
#  'Swimming / floating on his back',
#  'Spearfishing & holding catch',
#  'Washed into sea while picking opihi',
#  'Fell oveboard',
#  'Hookah Diving',
#  'Spent 8 days in dinghy',
#  'boat capsized during filming',
#  'Gathering fish stunned by dynamite',
#  'Filming',
#  'Wading with surfboard',
#  'Sinking of the M/V Mindoro during a typhoon',
#  'Paddle boarding',
#  'Fishing from boat, Kaimamla',
#  'Survived US Naval aircraft crash, climbing onboard rescue vessel when he fell back into sea ',
#  'Diving for coins thrown from ship S.S. Moeraki',
#  'Longling fishing',
#  'Jumped overboard to rescue companion',
#  'Rescuing seaman after ship sunk by German raider',
#  'Known as The Battle of the Bismarck Sea :  8 Japanese destroyers guarding a convoy of 8 transports were attacked by 129 Allied fighters, 207 bombers & 3 squadrons of the Royal Australian Air Force. ',
#  'Chasing shark out of bathing area while riding on a surf-ski',
#  'Diving in aquarium display tank',
#  'Salvaging a shipwreck',
#  'M.V. Tropical sank. Sole survivor rode oil drums for 8 days without food or water.',
#  'Crossing river on a raft',
#  'Fishing in waist-deep water',
#  'Thrown overboard',
#  'Carrying a supposedly dead shark by its mouth',
#  'Shell Diving',
#  'Spearfishing, Smith  & Walker touched shark with tip of their guns',
#  'Sleeping in anchored boat',
#  'Argentine Air Force C-54',
#  'Kitesurfing',
#  'Testing anti-shark cage',
#  'Conducting a promotional film project for the Gemini space program (a practice astronaut recovery)',
#  'Standing',
#  'Racing ski',
#  'Jumping in the waves',
#  'Watching the shark feeding on a dead pinniped',
#  'Sitting in a boat',
#  'Attempting to set underwater endurance record',
#  'Jumped into the water',
#  'Spearfishing on scuba',
#  'Fishing for perch',
#  'Swimming from naptha launch after a day of fishing',
#  'Standing, gathering oysters',
#  'Hunting lobsters in 2.4 m of water',
#  'Copra vessel with 19 on board was wrecked in a squall',
#  '3.3 m fishing boat sank. Treveluwe & Peter Hodgson (wearing lifejackets) were drifting in the current',
#  'Fishing',
#  'Fishing with hand line tied to wrist & was pulled into the water',
#  'Spearfishing, speared a small shark',
#  'Diving from dinghy for trochus shell',
#  'Spearfishing, shot shark, hauled it onto boat',
#  'Scallop diving (using surface-supplied air & a POD) ',
#  'Fishing, fell from rocks & disappeared',
#  ' ',
#  'Diving (Hookah)',
#  '.',
#  'Thrown into water from fishing dinghy',
#  'Fishing inside net',
#  'Standing, washing rear wheels of his ambulance in ankle-deep water',
#  'Swimming from capsized boat',
#  'A 75-ton  Japanese fishing ship was sunk by  Chinese Nationalist gunboat, shipwrecked men were clinging to debris',
#  'Fell overboard from the Sobella',
#  'Hunting crayfish',
#  'Fishing, lifting shark out of craypot',
#  'Standing on sandbank',
#  'Snorkeling, carrying a speared fish in her hand',
#  'Scuba diving for bivalves',
#  'Photographing the shark',
#  'Swimming, carrying tin can with mail to steamer',
#  'seaplane Columbus ditched in the sea',
#  'Splashing ',
#  'Swimming after boat became disabled',
#  'Standing / Wading',
#  'Floating ',
#  'Fishing for turtles',
#  'Swimming after his hat',
#  'Fishing on a boat',
#  'Kayaking (returning from spearfishing)',
#  "12 of the Penang's crew were returning to the ship when their 12' dinghy capsized",
#  'Swimming ashore from swamped 13-ft boat',
#  'Skindiving',
#  'Yacht Gooney Bird foundered, 4 survivors on raft',
#  "Fishing from 34' boat when pulled overboard by hooked shark",
#  'R5D aircraft went down with 29 on board',
#  'Scuba diving & spearfishing ',
#  'Collecting marine specimens',
#  'Surfing, pushing board ashore',
#  'Hand lining for shad',
#  'USS Gambier Bay CVE-73  shelled & sunk  at 09h57 on 10/24/1944, by Japanes fleet enroute to attack the Allied landing force at Leyte.',
#  'Fishing (trolling)  from canoe',
#  'The passenger ship Kapuna was run down the ore carrier Ada Melmore',
#  'Wading after stray fish from seine netter’s catch',
#  'Trochus diving, but floating on surface',
#  'Bathing in 2 feet of water',
#  'Swimming after their boat capsized',
#  'Spearfishing/ filming',
#  'Free diving & spearfishing (descending)',
#  "Crouching in 2' of water",
#  'Wreck of the schooner Driver',
#  'Floating on inner tube after diving for lobster',
#  'Small boat with 2 men onboard hit a submerged coral formation. Men began swimming to shore',
#  'Spearfishing, but swimming at surface',
#  'Working prawn net',
#  'Scuba diving, reportedly also spearfishing',
#  'Washed overboard by swell',
#  ...}

# %%
import re


for a in list(df["Activity"]):
    #print(re.findall(r"[Ss]urf", a), 'en:', a)
    print(re.findall(r"[Bb]oard", a),'en:', a)
# Out:
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing
# [] en: Wading
# [] en: Swimming
# [] en: Kite surfing
# ['board'] en: Boogie boarding
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Wading
# [] en: Snorkeling
# ['board'] en: SUP Foil boarding
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Kayaking
# [] en: Lobstering
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Fishing
# [] en: Fishing in Alabama Deep Fishing Rodeo
# [] en: Surfing
# [] en: Swimming
# [] en: Scuba Diving
# [] en: Wading
# [] en: Fishing for squid
# [] en: Fishing
# [] en: Fishing for sharks
# [] en: Swimming
# [] en: Fishing
# [] en: Surfing
# [] en: Scuba Diving
# [] en: Spearfishing
# [] en: Floating
# [] en: Wading
# [] en: Surfing
# [] en: Spearfishing
# [] en: Floating in tube
# [] en: Standing
# [] en: Surfing
# [] en: Swimming
# [] en: Diving
# [] en: Swimming
# [] en: Spearfishing
# [] en: Kite surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Teasing a shark
# [] en: Floating
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surf-skiing
# [] en: Swimming
# [] en: Spearfishing
# [] en: Spearfishing
# [] en: Walking
# [] en: Fishing
# [] en: SUP
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Body surfing
# [] en: Diving for beche-de-mer
# [] en: Fishing
# [] en: Swimming
# [] en: Kite surfing
# [] en: Spearfishing
# [] en: Wading
# [] en: Feeding stingrays?
# [] en: Surfing
# [] en: Walking
# [] en: Windsurfing
# [] en: Kayak fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Fishing
# ['board'] en: Paddle boarding
# [] en: Surfing
# [] en: Wading
# [] en: Spearfishing
# [] en: Kayak Fishing
# [] en: Swimming
# ['board'] en: Paddle boarding
# [] en: Surfing
# [] en: Scuba diving
# [] en: Sea disaster
# [] en: Fishing
# [] en: Lobster fishing
# [] en: Swimming / Wading
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Wading
# [] en: Fishing
# [] en: Spearfishing
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing for shrimp
# [] en: Surfing
# [] en: Swimming
# [] en: Kayak Fishing
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Wading
# [] en: Surfing
# [] en: Surfing
# [] en: Snorkeling
# [] en: Kayak fishing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Wading
# [] en: Photographing fish
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Stand-Up Paddleboarding
# [] en: Kayak Fishing
# [] en: Surf-skiing
# [] en: Wading
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Walking
# [] en: Kayak Fishing
# [] en: Swimming
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Floating
# [] en: Scallop diving on hookah
# [] en: Kayak Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Treading water
# [] en: Swimming
# [] en: Spearfishing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Swimming
# [] en: Surfing
# [] en: Playing in the water
# [] en: Swimming
# ['Board'] en: Body Boarding
# [] en: Swimming
# [] en: Surfing
# [] en: Standing
# [] en: Swimming
# [] en: Body surfing?
# [] en: Swimming
# [] en: Surfing
# [] en: Standing
# [] en: Spearfishing
# [] en: Swimming
# [] en: Wading
# [] en: Wading
# ['board'] en: Boogie boarding
# [] en: Playing
# [] en: Attempting to rescue a shark
# [] en: Surfing
# [] en: Standing
# [] en: Wading
# [] en: Spearfishing
# [] en: Swimming
# [] en: Surfing
# [] en: Snorkeling
# [] en: Swimming
# [] en: Surfing
# [] en: Diving
# [] en: Snorkeling
# [] en: Wading
# [] en: Surfing
# [] en: Surf skiing
# [] en: Photographing the shark
# ['board'] en: Paddle boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Diving
# [] en: Kayak Fishing
# [] en: Swimming
# [] en: Standing / Snorkeling
# [] en: Hand feeding sharks
# [] en: Fishing
# [] en: Fishing
# [] en: Sitting in the water
# [] en: Transatlantic Rowing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Bodysurfing
# [] en: Rowing
# [] en: Shark fishing
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing & filming dolphins
# [] en: Fishing
# [] en: Filming
# ['board'] en: Swimming after falling overboard
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Swimming
# [] en: Surfing
# [] en: Fishing
# [] en: Diving / Filming
# [] en: Spearfishing
# [] en: Fishing for blue sharks
# [] en: Surfing
# [] en: Fishing
# [] en: Fishing
# [] en: Surfing
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Stand-Up Paddleboarding
# ['board'] en: Stand-Up Paddleboarding
# [] en: Canoeing
# [] en: Surfing
# [] en: Surfing
# [] en: Standing in inner tube
# ['board'] en: Body surfing or Boogie boarding
# [] en: Fishing
# [] en: Kayaking
# [] en: Surfing
# [] en: Surfing
# [] en: Kayaking
# [] en: Kayaking
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Feeding fish
# [] en: Surfing
# [] en: Swimming
# [] en: Fishing
# [] en: Kayaking
# [] en: Fishing
# [] en: Playing with an air mattress
# [] en: Body surfing
# [] en: Surfing
# [] en: Fishing
# [] en: Swimming
# [] en: Surfing
# [] en: Standing
# [] en: Fishing for sharks
# ['board'] en: Kite boarding
# [] en: Spearfishing
# [] en: Standing
# [] en: Spearfishing
# [] en: Swimming
# [] en: Swimming
# ['board'] en: Boogie boarding
# [] en: Swimming
# [] en: Surfing
# [] en: Sea disaster
# [] en: Swimming
# [] en: Surfing
# [] en: Standing
# [] en: Wading
# [] en: Swimming
# [] en: Swimming
# [] en: Shark diving
# [] en: Body surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Body surfing
# [] en: Transatlantic Rowing
# [] en: Spearfishing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Petting a shark
# [] en: Fishing
# [] en: Standing
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Kneeling in the water
# [] en: Swimming
# [] en: Surfing
# [] en: Tagging sharks
# [] en: Fell into the water
# [] en: Scuba diving
# [] en: Teasing a shark
# [] en: Snorkeling
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Wading
# [] en: Surfing
# [] en: Diving
# [] en: Swimming
# [] en: Surfing
# [] en: Spearfishing
# [] en: Swimming
# [] en: Wading
# [] en: Shark watching
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Diving for lobsters
# [] en: Swimming
# [] en: Kite Surfing
# [] en: Surfing
# [] en: Kite Surfing
# [] en: Surfing
# [] en: Scuba diving / culling lionfish
# [] en: Swimming
# [] en: Surfing
# [] en: Kitesurfing
# [] en: Sailing
# [] en: Spearfishing / Free diving
# [] en: Fishing
# [] en: Surfing
# [] en: Fishing
# [] en: Spearfishing
# [] en: Sea disaster
# [] en: Filming a documentary
# [] en: Snorkeling
# [] en: Surfing
# [] en: Attempting to remove fishing net from submerged object
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Kayaking / Fishing
# ['board'] en: Body boarding
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Shark fishing
# ['board'] en: Body boarding
# [] en: Surfing
# ['board'] en: Kiteboarding
# [] en: Snorkeling
# ['board'] en: Body boarding
# [] en: Diving for crayfish
# [] en: Surfing
# [] en: Diving
# [] en: Surfing
# [] en: Wading
# [] en: Swimming / snorkeling
# [] en: Diving for Abalone
# [] en: Surfing
# [] en: Diving
# [] en: Standing
# [] en: Swimming
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Standing
# [] en: Swimming
# [] en: Casting a net
# [] en: Spearfishing
# [] en: Swimming
# [] en: Marathon swimming
# [] en: Longline fishing for sharks
# ['board'] en: Boogie boarding
# [] en: Wrangling a shark
# [] en: Surfing
# [] en: Surfing
# [] en: Snorkeling
# ['board'] en: Kiteboarding
# [] en: Surfing
# [] en: Attempting to free the shark
# [] en: Fishing
# [] en: Snorkeling
# [] en: Swimming
# [] en: Spearfishing
# [] en: Wading
# [] en: Surfing
# [] en: Cleaning fish
# [] en: Diving
# [] en: Swimming
# [] en: Walking in surf
# [] en: Swimming
# [] en: Swimming & snorkeling
# [] en: Swimming
# [] en: Wading
# [] en: Swimming
# [] en: Body surfing
# [] en: Fishing
# [] en: Kayaking / Fishing
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# ['Board'] en: Boogie Boarding
# [] en: Fishing for sharks
# [] en: Surfing
# [] en: Diving
# [] en: Swimming
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Fishing
# [] en: Swimming
# [] en: Fishing
# [] en: Playing in the surf
# [] en: Free diving
# [] en: Surfing
# ['board'] en: Kite boarding
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Free diving
# [] en: Snorkeling
# [] en: Fly fishing
# [] en: Fishing - 'tag & release'
# [] en: Surfing
# [] en: Spearfishing
# [] en: Spearfishing
# [] en: Swimming to shore with floatioon devices after boat engine conked out
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Scuba diving
# [] en: Fishing
# [] en: Surfing
# [] en: Dragging stranded shark into deeper water
# [] en: Surfing
# [] en: Spearfishing
# [] en: Spearfishing / Free diving
# [] en: Swimming
# [] en: Surfing
# ['board'] en: Paddle boarding
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Scuba diving
# [] en: Snorkeling
# [] en: Swimming
# [] en: Surfing
# [] en: Diving
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Paddle boarding
# [] en: Bathing
# [] en: Windsurfing
# ['board'] en: Bodyboarding
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Swimming or boogie boarding
# [] en: Shark fishing
# [] en: Surfing
# [] en: Swimming
# [] en: Wading or swimming
# [] en: Fishing
# [] en: Free diving
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Body surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Spearfishing
# [] en: Scuba diving
# [] en: Kayaking
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Sitting in the water
# [] en: Surfing
# [] en: Swimming
# [] en: Surf skiing
# [] en: Standing
# [] en: Wading
# [] en: Fishing
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Attempting to rescue an injured & beached shark
# [] en: Surf skiing
# [] en: Surfing
# ['Board'] en: Boogie Boarding
# [] en: Wading
# [] en: Free diving / spearfishing
# [] en: Surfing
# [] en: Kayak Fishing
# [] en: Spearfishing
# [] en: Kayaking / Fishing
# [] en: Swimming
# ['board'] en: Paddle boarding
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Kayaking
# [] en: Surfing
# [] en: Scuba diving
# [] en: Surfing
# [] en: Crayfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Diving, feeding sharks
# ['board'] en: Body boarding
# [] en: Kite Surfing
# [] en: Attempting to Kite surf from Egypt to Saudi Arabia
# [] en: Fishing (illegally)
# [] en: Kite Surfing
# [] en: Fishing
# [] en: Fishing
# [] en: Surfing
# [] en: Diving, photographing sharks
# [] en: Snorkeling
# [] en: Snorkeling
# [] en: Fishing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Canoeing
# [] en: Kayak Fishing
# [] en: Surfing
# [] en: Surf skiing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Kayaking
# [] en: Scuba diving
# [] en: Surfing
# [] en: Free diving / spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Diving
# [] en: Diving
# [] en: Surfing
# [] en: Diving
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Canoeing
# [] en: Wade fishing
# [] en: Surfing
# [] en: Fishing
# [] en: Swimming
# [] en: Spearfishing
# [] en: Jumping in the waves
# [] en: Canoeing
# ['board'] en: Body boarding
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Kite Surfing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Wade Fishing
# [] en: Standing, collecting sea stars
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Wading
# [] en: Swimming
# [] en: Surfing
# [] en: Floating
# [] en: Swimming or Snorkeling
# [] en: Playing in the surf
# [] en: Swimming
# [] en: Diving
# [] en: Swimming
# [] en: Sea disaster
# [] en: Wade Fishing
# [] en: Surfing
# ['Board'] en: Boogie Boarding
# [] en: Kayaking or Wave skiing
# [] en: Surf fishing
# [] en: Scuba diving
# [] en: Swimming
# [] en: Wade Fishing
# [] en: Surfing
# [] en: Kayaking
# [] en: Snorkeling
# [] en: Surfing
# [] en: Scuba diving
# [] en: Playing in the surf
# [] en: Surfing
# [] en: Jet skiing
# [] en: Spearfishing
# [] en: Surfing
# ['Board'] en: Boogie Boarding
# [] en: Fishing
# [] en: Scuba diving
# [] en: Spearfishing
# [] en: Spearfishing
# [] en: Wading
# [] en: Snorkeling
# ['board'] en: Standing or boogie boardin
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Paddle boarding
# ['Board'] en: Kite Boarding
# [] en: Spearfishing
# [] en: Body surfing
# [] en: Surfing
# [] en: Fishing
# [] en: Fishing
# [] en: Spearfishing
# [] en: Spearfishing
# [] en: Washing sand off a speared fish
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Diving
# [] en: Standing, holding shark pup
# [] en: Swimming
# [] en: Surfing
# [] en: Swimming
# [] en: Diving / fishing
# ['board'] en: Wakeboarding
# [] en: Surfing
# [] en: Fishing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Diving for abalone
# [] en: Fishing
# [] en: Snorkeling
# [] en: Shark fishing on the Ricardo Astorga
# [] en: Surf fishing
# [] en: Swimming
# [] en: Shark fishing on the Don Agustín-VI.
# [] en: Scuba diving
# [] en: Swimming
# [] en: Surfing
# [] en: Attempting to fix motor
# [] en: Fishing
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Snorkeling
# [] en: Surfing
# [] en: Snorkeling
# [] en: Snorkeling
# [] en: Snorkeling
# [] en: Snorkeling
# [] en: Fishing
# [] en: Swimming
# [] en: Snorkeling
# [] en: Diving
# [] en: Surfing
# [] en: Fishing
# [] en: Snorkeling
# [] en: Spearfishing
# [] en: Surfing
# [] en: Fishing
# [] en: Scuba diving
# [] en: Kite Surfing
# ['board'] en: Body boarding
# [] en: Snorkeling
# [] en: Surfing
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming /  Whale Watching
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming after boat became disabled
# ['Board'] en: Boogie Boarding
# [] en: Surfing
# [] en: Kayak Fishing
# [] en: Fishing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Windsurfing
# [] en: Swimming
# [] en: Kayaking
# [] en: Standing
# [] en: Standing
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Swimming
# [] en: Fishing
# [] en: Fishing
# [] en: Snorkeling
# [] en: Fishing
# [] en: Surfing
# ['board'] en: Stand-Up Paddleboarding
# [] en: Surfing
# ['Board'] en: Boogie Boarding
# [] en: Swimming
# [] en: Swimming
# ['Board'] en: Boogie Boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing
# [] en: Rescuing
# [] en: Swimming
# [] en: Surfing
# [] en: Scuba diving
# [] en: Wading
# [] en: Measuring sharks
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming / treading water
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Scuba diving
# [] en: Snorkeling
# [] en: Surfing
# [] en: Spearfishing
# ['board'] en: Body boarding
# [] en: Surf fishing / wading
# [] en: Spearfishing (free diving)
# ['Board'] en: Kite Boarding
# ['Board'] en: Boogie Boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Standing
# [] en: Snorkeling
# [] en: Bathing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Wading
# [] en: Swimming
# [] en: Swimming
# [] en: Kayaking
# [] en: Spearfishing
# [] en: Swimming to shore from capsized kayak
# [] en: Surfing
# [] en: Rowing
# [] en: Diving
# [] en: Surfing
# [] en: Wading
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Kayaking
# [] en: Surfing
# [] en: Kayaking
# [] en: Spearfishing
# ['board'] en: Paddle-boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Wading
# [] en: Diving
# [] en: Diving
# [] en: Surfing
# [] en: Fishing
# [] en: Swimming
# [] en: Fishing
# [] en: Swimming
# [] en: Swimming, attempting to rescue a girl  believed to be drowning
# [] en: Swimming
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# ['board'] en: Body boarding
# [] en: Swimming
# [] en: Surfing
# [] en: Wade Fishing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Swimming
# [] en: Washing his feet
# [] en: Wading
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Spearfishing
# [] en: Paddle-surfing
# [] en: Surfing
# ['Board'] en: Boogie Boarding
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Crawling
# [] en: Fishing for sharks
# [] en: Scuba diving
# [] en: Scuba diving
# [] en: Snorkeling
# [] en: Fishing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surf skiing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Swimming
# [] en: Spearfishing
# [] en: Wading
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Feeding fish
# [] en: Swimming
# [] en: Wading
# [] en: Surfing
# [] en: Fishing
# [] en: Fishing
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Diving, but on the surface when bitten by the shark
# [] en: Air Disaster
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing
# [] en: Spearfishing
# [] en: Fishing
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Fishing
# [] en: Surfing
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing
# [] en: Swimming
# [] en: Spearfishing
# [] en: Crabbing
# [] en: Yacht race
# ['Board'] en: Boogie Boarding
# [] en: Kayaking
# [] en: Snorkeling
# [] en: Kayaking
# [] en: Fishing
# [] en: Fishing
# [] en: Fishing
# [] en: Spearfishing
# [] en: Scuba diving
# [] en: Sinking of the cargo ship Mark Jason
# [] en: Fishing
# [] en: Fishing boat swamped in storm
# [] en: Fishing
# [] en: Scuba diving
# [] en: Spearfishing
# [] en: Fishing
# [] en: Surfing
# [] en: Fishing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Swimming, towing surfboard
# [] en: Surfing
# [] en: Swimming
# [] en: Treading water
# [] en: Wading
# [] en: Diving
# [] en: Surfing
# [] en: Swimming or surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Snorkeling
# [] en: Wading
# [] en: Wading
# [] en: Surfing
# [] en: Wading
# [] en: Diving
# [] en: Body surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Rowing an inflatable dinghy
# [] en: Wading
# [] en: Spearfishing
# [] en: Surf skiing
# [] en: Spearfishing (free diving)
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Kayaking
# [] en: Wading
# [] en: Surfing
# [] en: Body surfing
# [] en: Fishing
# [] en: Body surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Sea Disaster
# [] en: Surfing
# [] en: Surfing
# [] en: Night diving
# [] en: Swimming
# [] en: Fishing
# [] en: Wading
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Free-diving
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# ['Board'] en: Boogie Boarding
# [] en: Spearfishing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Walking out of the water after surfing
# [] en: Fishing from surfski
# [] en: Surfing
# [] en: Wading
# [] en: Walking out of the water after surfing
# [] en: Wading
# [] en: Jet skiing
# [] en: Surfing
# [] en: Diving
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surf-skiing
# [] en: Surf-skiing
# [] en: Accidentally stood on hooked shark's tail before attempting to gut it
# [] en: Wading
# [] en: Attempting to chase shark out to sea
# [] en: Surfing
# [] en: Fishing for snapper
# [] en: Surfing
# [] en: Surfing
# [] en: Scuba diving
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Removing fish from a trap
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Shark diving
# [] en: Floating
# [] en: Surf-skiing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: The 426-ton cargo ship Mia, laden with cement, capsized in heavy seas
# [] en: Swimming
# [] en: Spearfishing
# [] en: Surfing
# [] en: Swimming
# [] en: Scuba diving
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Wading?
# [] en: Surfing
# [] en: Snorkeling
# [] en: Wading
# [] en: Wading
# [] en: Standing
# [] en: Jumping
# [] en: Swimming
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Diving
# [] en: Fishing
# [] en: Swimming
# [] en: Surfing
# [] en: Playing
# [] en: Floating near boat & observing bioluminesce
# [] en: Swimming
# [] en: Walking out of the water after surfing
# [] en: Swimming
# ['Board'] en: Boogie Boarding
# [] en: Jumped into the water
# [] en: Surfing
# [] en: Surfing
# [] en: Surf paddling
# [] en: Kayak Fishing
# [] en: Snorkeling
# [] en: Wading
# [] en: Swimming
# [] en: Scuba diving
# [] en: Swimming
# [] en: Wading
# [] en: Spearfishing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Murder
# [] en: Removing hook from shark
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Wading
# [] en: Reviving a sedated shark
# [] en: Fishing
# [] en: Wading
# [] en: Surfing
# [] en: Surfing
# [] en: Snorkeling
# [] en: Swimming
# [] en: Snorkeling
# [] en: Swimming
# [] en: Sea Disaster
# [] en: Shark tagging
# [] en: Swimming / jumping off a jetty
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing
# [] en: Playing on a sandbar
# [] en: Surfing
# [] en: Murder
# [] en: Surfing
# [] en: Surfing
# [] en: Shark fishing
# [] en: Swimming
# [] en: Surfing
# [] en: Spearfishing
# [] en: Swimming
# ['Board'] en: Boogie Boarding
# [] en: Spearfishing
# [] en: Spearfishing (free diving)
# [] en: Shrimping
# [] en: Diving
# [] en: Swimming
# [] en: Swimming / Body Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing
# ['board'] en: Body boarding
# [] en: Sea Disaster
# [] en: Swimming
# [] en: Canoeing
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Playing soccer in the water
# [] en: Free diving / modeling
# [] en: Murder
# [] en: Spearfishing
# [] en: Surfing
# [] en: Diving / Kissing the shark
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Diving
# [] en: Standing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Spearfishing
# [] en: Sea Disaster
# [] en: Surfing
# [] en: Surfing
# [] en: Lifesaving drill
# [] en: Wading
# [] en: Spearfishing
# [] en: Touching sharks
# [] en: Surfing
# ['Board'] en: Boogie Boarding
# [] en: Surfing
# [] en: Surf-skiing
# [] en: Surfing
# [] en: Surf fishing
# [] en: Standing
# [] en: Swimming
# [] en: Swimming
# [] en: Wading
# [] en: Walking
# ['board'] en: Body boarding
# [] en: Swimming
# [] en: Spearfishing
# [] en: Spearfishing
# ['board'] en: Body boarding
# [] en: Fishing
# [] en: Spearfishing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Scuba diving
# [] en: Surfing
# [] en: Playing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Tagging sharks
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Scuba diving
# [] en: Swimming
# [] en: Snorkeling
# [] en: Surfing
# [] en: Standing
# [] en: Fishing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Swimming
# [] en: Wading
# [] en: Fishing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Standing
# [] en: Free diving
# [] en: Wading
# [] en: Swimming
# [] en: Fishing
# [] en: Surfing
# [] en: Swimming
# [] en: Kayaking
# [] en: Competing in the Woodvale Atlantic Rowing Race
# [] en: Spearfishing
# [] en: Competing in the Woodvale Atlantic Rowing Race
# [] en: Night Surfing
# [] en: Scuba diving
# [] en: Diving for lobsters
# [] en: Swimming
# [] en: Surfing
# [] en: Diving for crayfish
# [] en: Surfing
# [] en: Swimming
# [] en: Competing in the Woodvale Atlantic Rowing Race
# [] en: Spearfishing
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing for sharks
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Wading
# [] en: Standing
# [] en: Standing / Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Wading
# [] en: Surfing
# [] en: Scuba diving
# [] en: Treading water/ Surfing
# [] en: Diving
# [] en: Surf-skiing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Body surfing
# [] en: Surfing
# [] en: Standing
# [] en: Wading
# [] en: Surfing
# [] en: Standing / Surfing
# [] en: Removing shark from net
# [] en: Scuba diving
# [] en: Surfing
# ['board'] en: Boogie boarding, kicked at object in the water
# [] en: Swimming
# [] en: Walking
# [] en: Surfing
# [] en: Swimming
# [] en: Fishing
# [] en: Wading
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Scuba diving in aquarium tank
# [] en: Swimming
# [] en: Holding onto an inflatable boat
# [] en: Standing
# [] en: Fishing
# ['board'] en: Swimming with boogie board
# [] en: Swimming
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Diving
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Spearfishing (Free diving)
# [] en: Wading
# [] en: Swimming
# [] en: Crouching in 2' of water
# [] en: Surfing
# [] en: Spearfishing
# [] en: Kayaking
# [] en: Fishing
# [] en: Sea Disaster
# [] en: Surfing
# [] en: Fishing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Wading
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Snorkeling
# [] en: Diving in aquarium display tank
# [] en: Fishing
# [] en: Diving
# [] en: Swimming
# [] en: Spearfishing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Swimming
# [] en: Spearfishing
# [] en: Attempting to drive shark away from sailing regatta
# [] en: Fishing from a kayak
# [] en: Swept out to sea by the tsunami, she clung  to a log for 24 hours
# ['board'] en: Scurfing (surfboard being  towed behind a boat)
# [] en: Spearfishing
# [] en: Surfing
# [] en: Playing
# [] en: Swimming
# [] en: Surfing
# [] en: Snorkeling
# [] en: Diving
# [] en: Diving
# [] en: Chumming for white sharks
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing/ filming
# [] en: Surfing
# [] en: Surf fishing
# [] en: Swimming
# [] en: Jumping
# [] en: Walking
# [] en: Bathing
# [] en: Surfing
# [] en: Diving
# [] en: Swimming
# [] en: Spearfishing
# [] en: Fishing
# [] en: Surfing
# [] en: Diving & fishing with net
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Wading / fishing & carrying a bag of fish
# [] en: Fishing
# ['board'] en: Fishing for squid aboard the trawler Shikishima-Maru when the shark leapt into the boat
# [] en: Surfing
# [] en: Snorkeling
# [] en: Wading
# [] en: Surfing
# [] en: Crayfishing
# [] en: In water with diving seabirds
# ['board'] en: Body boarding
# [] en: Swimming
# [] en: Swimming, poaching perlemoen
# [] en: Wading
# [] en: Swimming
# [] en: Surfing
# ['board'] en: Boogie-boarding / swimming
# [] en: Swimming
# [] en: Wading
# [] en: Free diving & spearfishing
# [] en: Tandem surfing
# [] en: Swimming
# [] en: Diving
# [] en: Fishing
# [] en: Five men on makeshift raft after their 10 m fishing boat  capsized and sank in rough seas. Survivors rescued after  7.5 hours in the water
# [] en: Five men on makeshift raft after their 10 m fishing boat  capsized and sank in rough seas. Survivors rescued after  7.5 hours in the water
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Snorkeling
# [] en: Spearfishing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Swimming
# [] en: Surfing
# [] en: Swimming
# [] en: Free diving & spearfishing
# [] en: Snorkeling
# [] en: Snorkeling
# [] en: Scuba diving
# [] en: Surfing
# ['board'] en: Boogie boarding
# [] en: Swimming
# [] en: Spearfishing
# [] en: Surf skiing
# [] en: Diving
# [] en: Surfing
# [] en: Kayaking (returning from spearfishing)
# [] en: Air disaster. Flash Airlines Boeing 737 crashed into the Red Sea
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming / shipwreck
# [] en: Surfing amid a shoal of sharks
# [] en: Swimming
# [] en: Swimming
# [] en: Spearfishing
# [] en: Surfing
# [] en: Swimming or surfing
# [] en: Surfing
# [] en: Snorkeling
# [] en: Surf skiing
# [] en: Standing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Snorkeling
# [] en: Surfing
# [] en: Swimming to shore from boat or kayak
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Sitting on surfboard
# [] en: Wading near a fishing net
# [] en: Wading to shore from his boat
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing
# [] en: Swimming
# ['board'] en: Body boarding
# [] en: Standing, stepped on shark
# ['board'] en: Body boarding
# [] en: Wade-fishing
# [] en: Fishing
# [] en: Swimming, wearing black wetsuit & swim fins
# [] en: Swimming
# ['board'] en: Sitting on surfboard
# [] en: Surf skiing
# [] en: Surfing
# [] en: Wading
# [] en: Spearfishing
# ['board'] en: Walking, carrying surfboard & stepped on shark
# [] en: Surfing
# [] en: Spearfishing
# [] en: Spearfishing
# [] en: Spearfishing
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Standing
# [] en: Swimming with pod of dolphins
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Wading
# [] en: Swimming
# [] en: Surfing
# [] en: Walking
# [] en: Killing  sharks
# [] en: Swimming
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Jumping
# [] en: Surfing
# [] en: Swimming (using a float)
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Petting captive sharks
# [] en: Scuba diving
# [] en: Wading
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Unknown
# [] en: Surfing
# [] en: Surfing
# [] en: Snorkeling
# [] en: Snorkeling
# [] en: Scuba diving
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Scuba diving
# ['board'] en: Body boarding
# [] en: Swimming
# [] en: Snorkeling
# [] en: Surfing
# ['board'] en: Boogie boarding
# [] en: Fishing, standing in 2' of water
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Fishing from Surfboard
# [] en: Fishing
# [] en: Swimming
# ['board'] en: Boogie boarding or Surfing
# [] en: Surfing
# [] en: Swimming
# ['board'] en: Body boarding
# [] en: Surf skiing
# ['board'] en: Boogie boarding
# [] en: Wading, when he stepped on the shark
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Standing
# [] en: Diving
# [] en: Standing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Shark Fishing
# [] en: Surfing
# [] en: Standing
# [] en: Surfing
# [] en: Swimming
# [] en: Attempting to retreive a dinghy
# ['board'] en: Sitting on surfboard
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Snorkeling (filming the sardine run)
# [] en: Surfing
# [] en: Floating on a raft
# [] en: Fishing, removing the shark from his line
# [] en: Playing in the surf with his 2 dogs
# [] en: Surfing
# [] en: Collecting beche-de-mer
# [] en: Fishing
# [] en: Surfing
# [] en: Fishing from prawn trawler
# [] en: Scallop diving (using surface-supplied air & a POD)
# [] en: Fishing (Drowned 2-Apr-2002)
# ['board'] en: Surfing, but standing in water alongside board
# [] en: Surfing
# [] en: Swimming
# [] en: Standing
# [] en: Wading
# [] en: Swimming / Wading
# ['board'] en: Body-boarding
# [] en: Wading
# [] en: Swimming
# ['board'] en: Swimming /  boogie boarding
# [] en: Snorkeling
# [] en: Surfing
# [] en: Spearfishing
# [] en: Capsized fishing boat
# [] en: Surfing
# [] en: Kayaking
# [] en: Surfing
# [] en: Swimming
# [] en: Fishing
# [] en: Swimming
# [] en: Surf skiing
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surf-skiing
# ['Board'] en: Kite-Boarding
# [] en: Snorkeling
# [] en: Body surfing
# ['board'] en: Surfing, fell off surfboard & stepped on the shark.
# [] en: Surfing
# [] en: Wreck / Technical diving
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Diving
# [] en: Fishing
# [] en: Walking in shallows
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Wading
# [] en: Swimming
# [] en: Spearfishing
# [] en: Standing
# [] en: Wading
# ['Board'] en: Boogie Boarding
# ['Board'] en: Boogie Boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Fell off banana boat
# [] en: Swimming
# [] en: Fishing
# [] en: Fishing
# [] en: Surfing
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Swimming
# [] en: Floating face-down in knee-deep water
# [] en: Swimming
# [] en: Spearfishing
# [] en: Hiking on the beach
# [] en: Wading
# [] en: Swimming
# [] en: Swimming
# [] en: Shark fishing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing, carrying his catch
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Snorkeling
# ['board'] en: Standing alongside surfboard
# [] en: Batin
# [] en: Surfing
# ['board'] en: Body-boarding
# [] en: Surfing
# [] en: Attempting to catch a crocodile
# [] en: Swimming
# ['board'] en: Sinking of the 40' Esperanza off St. Maartin with 36 refugees on board
# [] en: Fishing for whiting
# [] en: Unknown
# [] en: Surfing
# [] en: Kayaking
# [] en: Swimming
# [] en: Fishing
# [] en: Surfing
# [] en: Kayaking
# [] en: Scuba diving
# [] en: Swimming back from anchored sailboat
# [] en: Fishing for whiting
# [] en: Diving for sea urchins
# [] en: Spearfishing
# [] en: Surfing
# [] en: Diving (shell maintenance)
# [] en: Shipwrecked
# [] en: Swimming
# [] en: Walking
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing
# [] en: Swimming / snorkeling
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Body surfing
# [] en: Surfing
# ['board'] en: Sitting on surfboard
# [] en: Surfing
# [] en: Surfing
# [] en: Fell onto dead shark
# [] en: Surfing
# [] en: Standing / surfing
# [] en: Surfing
# [] en: Swimming / Body surfing
# [] en: Swimming
# [] en: Free diving
# [] en: Swimming
# [] en: Wading
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Jumped into the water
# [] en: Conducting research
# [] en: Swimming out to porpoises
# ['board'] en: Windsurfing, but sitting on his board
# [] en: Surfing / Wading
# [] en: Standing
# [] en: Swimming
# [] en: Attempting to illegally enter the USA
# [] en: Swimming
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Scuba diving
# [] en: Wading
# [] en: Swimming
# [] en: Jumping
# [] en: Playing
# [] en: Wading
# [] en: Spearfishing, holding mesh bag with speared fish
# [] en: Wading
# [] en: Standing
# [] en: Swimming
# [] en: Fishing
# [] en: Standing
# [] en: Sailing
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Snorkeling
# [] en: Swimming
# ['board'] en: Air Disaster - Piper aircraft crashed into the sea, killing all on board
# [] en: Standing
# [] en: Diving
# [] en: Walking
# ['board'] en: Boogie boarding / wading
# [] en: Fishing
# [] en: Swimming
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Rowing
# [] en: Rowing
# [] en: Kayaking
# [] en: Swimming
# [] en: Spearfishing
# [] en: Body surfing
# [] en: Feeding prawns to captive sharks
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Canoe with 3 men onboard sank
# [] en: Diving
# [] en: Fishing for tarpon
# [] en: Surfing
# [] en: Swimming
# [] en: Bathing
# [] en: Surfing
# [] en: Scuba diving
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# ['board'] en: Surfing (sitting on his board)
# [] en: Surfing
# [] en: Spearfishing, but swimming at surface
# [] en: Swimming
# [] en: Swimming
# ['board'] en: Body boarding
# [] en: Body surfing
# [] en: Surfing
# ['board'] en: Surfing, lying on surfboard
# [] en: Wading to shore after surfing
# [] en: Fishing
# [] en: Wading
# [] en: Wading
# [] en: Surfing
# [] en: Wading
# ['board'] en: Wading with surfboard
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing
# [] en: Lying prone in 2' of water
# [] en: Body surfing
# [] en: Spearfishing & holding catch
# [] en: Surfing
# [] en: Swimming with dolphins
# [] en: Surfing
# ['board'] en: Boogie boarding
# [] en: Wading in school of baitfish
# [] en: Surfing
# [] en: Adrift in a life jacket
# [] en: Surfing
# [] en: Swimming
# [] en: Splashing / wading
# [] en: Windsurfing
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming after being swept into sea by a large wave
# [] en: Surfing
# [] en: Spearfishing & diving for paua
# [] en: Scientific research (Dr. Sonny Gruber's student)
# [] en: Swimming, towing a kayak
# [] en: Spearfishing
# [] en: Fishing
# ['board'] en: Body surfing or body boarding
# [] en: Swimming near pod of whales
# [] en: Cruising
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Paddle Skiing
# [] en: Inflatable boat
# [] en: Fishing
# [] en: Spearfishing
# [] en: Spearfishing
# [] en: Body surfing
# [] en: Surfing
# [] en: Standing
# [] en: Surfing
# [] en: Splashing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Walking
# [] en: Surfing
# [] en: Fishing for tuna
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Diving
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing / washing bait off hands
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Fishing
# ['board'] en: Boogie boarding
# [] en: Spearfishing
# [] en: Spearfishing
# ['board'] en: Body-boarding
# [] en: Moving a shark in a net
# ['board'] en: Surfing (or body boarding)
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Wading
# [] en: Surfing
# [] en: Surfing
# [] en: Free diving for abalone
# ['Board'] en: Body Boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Body boarding
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming / surfing
# ['board'] en: Body boarding
# [] en: Towing rubber dinghy
# ['board'] en: Surfing (lying prone on his board)
# [] en: Scuba diving
# [] en: Swimming
# [] en: Swimming
# [] en: Snorkeling – hunting crayfish and abalone
# ['board'] en: Swimming or paddle boarding
# [] en: Swimming
# [] en: Spearfishing
# [] en: Windsurfing
# [] en: Bathing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Diving
# [] en: Spearfishing on scuba & transferring fish onto a stringer
# [] en: Spearfishing
# ['board'] en: Sitting on surfboard
# [] en: Swimming
# [] en: Scuba diving (submerged riding a scooter)
# [] en: Swimming
# [] en: Unknown
# [] en: Surf-skiing
# ['board'] en: Body boarding or surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Fishingat
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Walking / surfing
# ['board'] en: Surfing (sitting on his board)
# [] en: SCUBA diving
# [] en: SCUBA diving
# [] en: Floating on raft
# [] en: Fishing
# [] en: Fishing
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Wading
# [] en: Wade-fishing
# [] en: Body surfing
# [] en: Wading / Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Standing
# [] en: Fishing for octopus
# [] en: Surfing
# [] en: Spearfishing / night diving
# [] en: Snorkeling
# [] en: Surfing
# [] en: Bathing
# [] en: Body surfing, stood up on sandbar
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Spearfishing
# [] en: Windsurfing
# [] en: Swimming
# [] en: Scuba diving
# [] en: Rowing
# [] en: Snorkeling
# [] en: Windsurfing
# [] en: Spearfishing
# [] en: Watching seals
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Attempting to attract dolphins
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming or snorkeling
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Diving for abalone
# [] en: Surfing / Swimming
# [] en: Standing
# ['board'] en: Sitting on surfboard
# ['board'] en: Boogie boarding
# [] en: Spearfishing
# ['Board'] en: Body Boarding
# [] en: Free diving for abalone
# [] en: Wade fishing
# [] en: Standing
# [] en: Swimming
# [] en: Free diving with a pod of dolphins
# [] en: Swimming
# [] en: Swimming
# [] en: Standing
# [] en: Diving
# [] en: Body surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Tech diving
# [] en: Surfing
# [] en: Shell Diving
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming breast stoke
# [] en: Fishing in knee-deep water
# [] en: Dived naked into the water on a bet
# [] en: Swimming in fish tank
# [] en: Diving
# [] en: Boeing 757 enroute from Porta Plata plunged into the sea
# [] en: Swimming
# [] en: Wading
# [] en: Swimming
# [] en: Swimming with mask & snorkel
# [] en: Chumming for sharks
# [] en: Surfing
# [] en: Surfing
# [] en: Diving, gathering shellfish
# [] en: Fell off aircraft carrier
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Playing / standing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Windsurfing
# [] en: Surfing
# [] en: Swimming
# ['board'] en: Body-boarding
# [] en: Scuba diving
# [] en: Abalone diving using Hookah (near calving whales)
# [] en: Abalone diving using Hookah (resting on the surface)
# [] en: Swimming
# [] en: Surfing
# [] en: On a float
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Surfing
# [] en: Diving
# [] en: Fishing
# [] en: Wading
# [] en: Swimming
# [] en: Surfing
# ['board'] en: "Riding waves on a board"
# ['board'] en: Body boarding
# [] en: Fishing
# [] en: Diving
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Standing
# [] en: Swimming
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Fishing
# ['board'] en: Jumped off surfboard & landed on the shark
# [] en: Scuba diving (ascending using scooter)
# [] en: Kayaking
# [] en: Playing / jumping
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Diving
# [] en: Surfing
# [] en: Sleeping in anchored boat
# [] en: Diving for abalone
# [] en: Diving
# [] en: Scuba diving for bivalves
# [] en: Surf skiing
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# [] en: Wind surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Diving
# [] en: Snorkeling
# [] en: Scuba diving
# ['board'] en: Body boarding
# ['board'] en: Surfing, sitting on board
# [] en: Surfing
# [] en: Surfing
# [] en: Murder victim
# [] en: Commercial diver (submerged or treading water)
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing, paddling seawards
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Wading
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Adrift on refugee raft
# [] en: Jumped off rocks into white water
# [] en: Surfing
# [] en: Swimming
# [] en: Windsurfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Wading
# [] en: Wading
# [] en: Surfing
# [] en: Wading
# [] en: Freediving for seashells
# [] en: Spearfishing
# [] en: Swimming alongside NOAA research vessel Discoverer
# [] en: Swimming alongside NOAA research vessel Discoverer
# [] en: Removing shark from tank in nightclub
# [] en: Surfing
# [] en: Spearfishing
# [] en: Surfing
# [] en: Fishing
# [] en: Surfing
# [] en: Fishing
# [] en: Swimming
# [] en: Surfing
# [] en: Windsurfing
# [] en: Fishing
# ['board'] en: Swimming, after falling off towed kneeboard
# [] en: Swimming
# [] en: Playing volleyball with friends
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Hookah diving
# [] en: Surfing, paddling shorewards
# [] en: Stamding
# [] en: Surfing
# [] en: Swimming
# [] en: Kayaking
# [] en: Surfing
# [] en: Swimming
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing
# [] en: Wading
# [] en: Swimming
# [] en: Spearfishing
# [] en: Surfing
# [] en: Surfing, paddling seawards
# [] en: Watching the shark feeding on a dead pinniped
# [] en: Riding floatation device
# [] en: Fishing
# [] en: Free diving for abalone (ascending)
# [] en: Fishing for lobsters
# [] en: Oyster fishing
# [] en: Surfing
# [] en: Playing
# [] en: Swimming
# ['board'] en: Body boarding
# [] en: Swimming
# [] en: Scuba diving
# ['board', 'board'] en: Paddling on surfboard or body board
# [] en: Scuba diving
# [] en: Scuba diving at seal colony
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Spearfishing
# [] en: Surfing
# [] en: Floating on his back
# ['board'] en: Paddling on surfboard
# [] en: Free diving & spearfishing (ascending)
# [] en: Swimming
# [] en: Sea disaster
# [] en: Sea disaster
# [] en: Fishing
# ['board'] en: Body boarding
# [] en: Spearfishing
# [] en:
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Snorkeling
# [] en: Standing in waist-deep water, helping his father tend a gill net containing dead fish
# ['board'] en: Lying on surfboard
# [] en: Spearfishing / free diving
# [] en: Surfing
# [] en: Surfing
# [] en: Kayaking
# [] en: Scuba diving
# [] en: Scuba diving (submerged)
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Hookah diving for sea urchins
# [] en: Surfing
# [] en: Scuba diving
# ['board'] en: Boogie boarding
# [] en: Surfing
# ['board'] en: Body boarding
# [] en: Surfing
# [] en: Standing
# [] en: Swimming
# [] en: Surf fishing
# [] en: Snorkeling, carrying a speared fish in her hand
# [] en: Surfing
# [] en: Fell from cliff while fishing & disappeared in strong current
# [] en: Surfing
# [] en: Snorkeling
# [] en: Fisherman
# [] en: Zosimo & his son, Jeffrey Popa, failed to return from overnight fishing trip in a 14' boat, Boat apparently sank, debris recovered but his son & boat were never found
# [] en: Standing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Swimming
# [] en: Preparing to fish for jack-mackerel
# [] en: Diving
# [] en: Scuba diving
# [] en: Surfing
# [] en: Scuba diving & filming
# [] en: Snorkeling
# [] en: Surfing
# [] en: Surfing, paddling seawards
# [] en: Surfing
# [] en: Hookah diving for pen shells
# [] en: Fishing for yellowtail, Seriola quinqueradiata
# ['board'] en: Surfing (sitting on his board)
# ['board'] en: Body boarding
# [] en: Diving for pen shells
# [] en: Surfing
# [] en: Spearfishing
# ['board'] en: Boogie boarding
# [] en: Swimming
# [] en: Spearfishing
# [] en: Fishing
# [] en: Hookah diving for sea urchins
# [] en: Snorkeling
# [] en: Snorkeling
# [] en: Fishing from rocks, swept out to sea by large wave & treading water
# [] en: Fishing
# ['board'] en: Boogie boarding
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Scuba diving
# [] en: Finning the shark that bit him
# [] en: Swimming
# [] en: Wading
# [] en: Fishing
# [] en: Canoeing
# [] en: Snorkeling
# [] en: Swimming from makeshift raft  to life vest after fishing boat sank
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Boogie boarding
# [] en: Fishing
# [] en: Surfing
# [] en: Swimming behind sailboat
# [] en: Swimming
# ['board'] en: Sitting on surfboard
# [] en: Scuba diving
# [] en: Fishing
# [] en: Diving
# [] en: Surfing, collided with shark
# ['board'] en: Sitting on surfboard
# [] en: Scuba diving
# [] en: Surfing
# [] en: Spearfishing
# [] en: Swimming
# [] en: Surf-skiing
# ['board'] en: Surfing (or sailboarding)
# [] en: Swimming
# [] en: Scuba diving (but on surface)
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# ['board'] en: Free diving / spearfishing, from paddleboard & floating on the surface
# [] en: Kayaking
# [] en: SCUBA diving
# [] en: Surfing
# [] en: Surfing
# [] en: Wade fishing
# [] en: Wading
# [] en: Surfing
# [] en: Scuba diving (but on surface)
# [] en: Spearfishing
# [] en: Fishing
# ['board'] en: Resting on surfboard
# ['board'] en: Lying on surfboard & paddling
# [] en: Surfing
# [] en: Free diving for trochus
# [] en: Surfing
# [] en: Surfing
# ['board'] en: Sitting on surfboard
# [] en: Swimming
# [] en: Surfing
# [] en: Scuba diving & spearfishing
# ['Board'] en: Board sailing
# ['board'] en: Surfing (sitting on his board)
# [] en: Surfing
# ['board'] en: On board 51' fishing vessel One Ki
# [] en: Swimming
# [] en: Surfing
# [] en: Free diving & spearfishing
# [] en: Wading, knocked down & swept away by large waves
# [] en: Swimming in canal
# [] en: Swimming
# [] en: Surfing
# [] en: Scuba diving
# [] en: Surfing
# [] en: Diving
# [] en: Surfing
# [] en: Free diving
# [] en: Fishing, stepped on hooked shark's head
# [] en: Observing a shark feeding on a carcass of a humpback whale
# [] en: Hookah diving for abalone (descending)
# [] en: Surfing
# [] en: Filming 5' blue shark
# [] en: Feeding fish
# [] en: Swimming
# [] en: Surfing
# [] en: Surfing
# [] en: Spearfishing
# [] en: Fishing for sharks
# [] en: Scuba diving
# [] en: Surfing
# [] en: Surfing
# [] en: Surfing
# [] en: Playing
# ['board'] en: Fell off surfboard 20' from shore
# [] en: Spearfishing
# ['board'] en: Windsurfing (urinating on his board)
# [] en: Surfing
# [] en: Free diving
# [] en: Swimming
# ['board'] en: Surfing (lying prone on his board)
# ['board'] en: Paddling on surfboard
# ['board'] en: Paddling on surfboard
# [] en: Surfing
# [] en: Kayaking
# [] en: Fishing
# [] en: Windsurfing
# [] en: Scuba diving, but swimming on surface
# [] en: Kayaking
# [] en: Kayaking
# ['board'] en: Body boarding
# [] en: Lifesaving drill
# [] en: Swimming in strong current with 3 others when he disappeared
# [] en: Surfing with dolphins
# [] en: Scuba diving, hand feeding sharks
# [] en: Spearfishing using scuba & trailing a string of bleeding fish
# [] en: Skindiving
# [] en: The Christie V sank on 11/6/1988, survivors were adrift on a dinghy
# [] en: The Christie V sank on 11/6/1988, survivors were adrift on a dinghy
# [] en: The MV Dona Marilyn sank in Typhoon Unsang with the loss of 389 lives
# ['board'] en: Surfing (sitting on his board)
# ...
# [] en: Fishing
# ['board'] en: Swimming, after falling overboard
# [] en: Swimming
# [] en: Bathing
# [] en: Suicide
# [] en: Swimming
# [] en: Sponge diving
# [] en: Fishing
# [] en: Swimming
# [] en: Swimming
# [] en: Fishing
# [] en: Swimming
# [] en: Fishing
# [] en: Catching crabs
# [] en: Fishing
# [] en: Swimming
# [] en: Sponge diving
# [] en: Swimming
# [] en: Standing on ship deck
# [] en: Dangling feet in the water
# [] en: Swimming
# [] en: Bathing
# [] en: Taking catch from a fish weir in which the shark was snared
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Diving around anchored liner
# [] en: Swimming
# [] en: Bathing
# [] en: Bathing
# [] en: Bathing
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Diving
# [] en: Floating
# [] en: Bathing
# [] en: Swimming
# [] en: Hunting seashells
# [] en:
# [] en: Standing, gathering oysters
# [] en: Swimming
# [] en: Fell into the water
# [] en: Sea Disaster
# [] en: Diving
# [] en: Sponge diving
# [] en: Swimming
# [] en: Hunting sharks
# [] en: Swimming
# [] en: Floating on his back
# [] en: Bathing
# [] en: Bathing
# ['board'] en: Fell overboard
# [] en: Fishing
# [] en: Attempting to land a boat from the Hinemoa
# [] en: Swimming
# [] en: Bathing
# [] en: Bathing
# [] en: Dangling feet in the water
# [] en: Rowing
# [] en: Hunting crayfish
# ['board'] en: Fell oveboard
# ['board'] en: Jumped overboard
# [] en: Diving
# [] en: Diving
# [] en: Swimming
# [] en: Swimming after their boat capsized
# [] en: Swimming at side of small boat
# [] en: Standing
# [] en: Swimming
# [] en: boat from City of Naples capsized
# [] en: The cutter Francis Adams foundered
# [] en: Sponge divers
# [] en: Fishing (Seining)
# [] en: 13 men in the water after sailboat capsized & sank
# [] en: Trailing hand in the water
# [] en: Attempting to escape by swimming to shore
# [] en: Diving for coins
# [] en: Loss of the schooner Nomad
# [] en: Angling
# [] en: Diving
# [] en: Fishing
# [] en: Fishing
# [] en: Standing
# [] en: Wading after stray fish from seine netter’s catch
# [] en: Wreck of the steamship Sultan of Bombay
# [] en: Swimming
# [] en: Fishing
# [] en: Fishing
# [] en: Bathing
# [] en: Swimming
# [] en: Boat swamped
# [] en: Diving
# [] en: Fishing
# [] en: Bathing
# [] en: Bathing
# [] en: Swimming ashore from a "filibuster"
# [] en: Wading
# [] en: Bathing
# [] en: Diving for coins
# [] en: Fishing
# [] en: Shipwreck
# [] en: Diving for coins
# [] en: Fishing
# [] en: Swimming
# [] en: Fishing
# [] en: Hunting seals
# [] en: Diving
# [] en: Pearl diving
# [] en: Sea Disaster : Wreck of the Carrie E. Long
# [] en: "Boat accident"
# [] en: "Crossing the river"
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming, after sailboat capsized
# [] en: Fishing
# [] en: Bathing
# [] en: Swimming
# [] en: Bathing
# [] en: Dangling feet in the water
# [] en: Fishing
# [] en: Swimming
# [] en: Swimming / floating on his back
# [] en: Fishing
# [] en: Bathing
# [] en: Swimming after harpooned whale capsized boat
# [] en: bathing
# [] en: Fell from yardarm of British ship Rover
# [] en: Bathing
# [] en: Bathing
# [] en: Murder
# [] en: small boat
# [] en: Abandoning burning steamship Don Juan
# [] en: HMS Victoria collided with the HMS Camperdown
# [] en: A barque wrecked
# [] en: Canoe swamped
# [] en: His balloon crashed in the harbor
# ['board'] en: Swimming after falling overboard from the sealing ship Vesper
# [] en: Boat capsized, swimming ashore
# [] en: Boat capsized, swimming ashore
# [] en: Bathing
# [] en: Murdered
# ['board'] en: Fell overboard
# [] en: Fishing
# [] en: Swimming
# [] en: Fishing boat
# [] en: Riding a horse
# [] en: Bathing
# ['board'] en: Fell overboard from sponge vessel
# [] en:  a canoe was pursuing a schooner that had forcibily abducted 5 young girls
# [] en: Fishing
# [] en: Dress diving
# [] en: Swimming
# [] en: Swimming, after boat swamped
# [] en: Sea Disaster, canoes capsized in storm
# ['board'] en: Knocked overboard
# [] en: Shooting sharks
# ['board'] en: Fishing for sharks when he became entangled in net & fell overboard
# [] en: Fleeing across a river
# [] en: boat capsized
# [] en: Swimming to shore after boat capsized by a squall
# ['board'] en: Thrown overboard
# ['board'] en: Thrown overboard
# [] en: Fishing for bluefish
# [] en: Treading for clams
# [] en: Bathing
# [] en: Swimming
# ['board'] en: Fell overboard
# [] en: Swimming
# ['board'] en: Fishing boat with 4 men on board was rammed & capsized by  a shark, throwing all occupants into the water
# [] en: Wading
# [] en: Diving
# [] en: Diving
# [] en: Swimming
# [] en: Bathing
# [] en: Fell into the water
# [] en: Parachuted from balloon
# [] en: Swimming
# [] en: Swimming
# [] en: Fishing
# [] en: Fell into the water
# [] en: Fishing
# [] en: Cleaning the side of a ship
# [] en: Swimming
# [] en: Swimming
# [] en: Working on the bridge when he fell into the river
# [] en: The steamships Thingvalla and Geiser collided
# [] en: Sailing
# [] en: Probabable drowning
# [] en: The Dwarka foundered
# [] en: Fishing
# [] en: The cutter yacht Cutty Sark sank
# [] en: Floating on his back
# [] en: Crossing the river mouth
# [] en: Rowing
# [] en: Sponge diving
# ['board'] en: Fell oveboard from steamer Wanderer
# [] en: Crossing inlet in a boat, seen fighting sharks with his oar, sharks smashed boat
# [] en: Sea disaster, wreck of the Alfred Watts
# [] en: Swimming
# [] en: Rowing a dinghy
# [] en: Swimming
# [] en: The passenger ship Kapuna was run down the ore carrier Ada Melmore
# [] en: Swimming
# [] en: British ship Macedon was thrown on her beam ends by a sudden squall
# [] en: Netting menhaden, sharks caught in net
# [] en: Clamming
# ['board'] en: Swimming after being washed overboard
# [] en: Fishing from shore, washed into the sea
# [] en: Bathing
# [] en: Oystering
# [] en: Sea disaster : Wreck of the Taiaroa
# [] en: Bathing
# [] en: He drowned when boat capsized
# [] en: Fishing
# [] en: Diving off jetty
# [] en: Diving alongsidethe steamship Ranelagh
# [] en: Swimming
# [] en: Sailing
# [] en: Bathing
# ['board'] en: Fell or jumped overboard from the liner Rhynland
# [] en: Wreck of the schooner Pohoiki
# [] en: Wreck of the schooner Pohoiki
# [] en: Wreck of the schooner Pohoiki
# [] en: Swimming
# [] en: Bathing
# [] en: Fishing
# [] en: yachting accident
# [] en: Boating
# [] en: Clamming
# [] en: Swimming
# ['board'] en: Fell overboard
# [] en: Swimming
# [] en: Swimming / escaping imprisonment
# [] en: Fishing for sharks
# [] en: Diving
# [] en: Diving
# [] en: Bathing
# [] en: Fishing
# ['board'] en: Fell overboard
# [] en: Restraining a beached shark
# [] en: Bathing
# [] en: Bathing
# [] en: Clinging to shipwrecked junk
# ['board'] en: Fell overboard
# [] en: Pearl diving
# [] en: Fishing
# [] en: Pearl diving
# [] en: Bathing
# ['board'] en: During "an exhibition" he was tied in sack & thrown overboard
# [] en: Swimming
# [] en: Bathing
# [] en: Bathing
# [] en: Floating, holding onto an oar after dory capsized
# [] en: Swimming
# [] en: Bathing
# ['board'] en: Fell overboard
# [] en: Fishing on a boat
# [] en: Swimming
# [] en: Traveling by boat
# [] en: Swimming to retrieve a flannel
# [] en: Sailing
# [] en: Bathing in river
# [] en: Bathing in river
# [] en: Bathing
# [] en: Fishing
# [] en: Bathing
# [] en: Diving for sponges
# [] en: Swimming
# [] en: Swimming
# [] en: Fishing
# [] en: Bathing
# [] en: Standing
# [] en: The steamship Bonnie Dundee lost in collision
# [] en: Floating with life buoy after pilot launch capsized
# [] en: Bathing
# [] en: Swimming
# ['board'] en: Jumped overboard after murdering 2 shipmates
# [] en: Fishing
# [] en: Boat with 5 men capsized while returning to the Amerique
# [] en: Boat with 5 men capsized while returning to the Amerique
# [] en: Swimming
# [] en: Swimming
# [] en: Wreck of the Union Steamship Company 982-ton iron steamer Kafir
# [] en: Bathing in 2 feet of water
# [] en: Bathing
# ['board'] en: Washed overboard from the barque Mary Eady
# [] en: Fishing
# [] en: Bathing
# [] en: Paddling
# [] en: Fishing
# [] en: Bathing
# [] en: Swimming
# [] en: Body found floating next to his ship
# [] en: Diving for sponges
# [] en: Bathing
# [] en: Swimming
# [] en: Bathing
# [] en: Sponge diving
# [] en: Pearl diving
# [] en: Fishing
# [] en: Bathing
# [] en: Bathing
# [] en: Bathing
# [] en: Sitting on gunwale of boat
# [] en: Fishing
# [] en: Fishing
# [] en: Fishing
# [] en: Bathing
# [] en: Escaping from blackbirding vessel
# [] en: Salvaging a shipwreck
# [] en: Fishing
# [] en: Bathing
# [] en: Fleet of canoes caught by a squall and charged by sharks.
# [] en: Fishing (Seining)
# [] en: Bathing
# [] en: Bathing
# [] en: Swimming / escaping imprisonment
# [] en: Swimming to avoid capture
# [] en: Fishing
# [] en: Canoeing
# [] en: Wreck of the 150-ton brig Maria
# [] en: boat capsized
# [] en: Adrift on a raft
# [] en: Fishing
# [] en: Shark fishing
# [] en: Bathing
# [] en: Bathing
# [] en: Fishing
# [] en: Bathing
# [] en: Bathing
# [] en: Bathing / standing
# [] en: Fishing
# [] en: Bathing
# [] en: Bathing
# [] en: Bathing
# [] en: Canoeing
# [] en: Net fishing
# ['board'] en: Fell overboard
# [] en: Standing
# [] en: A junk foundered
# [] en: Fishing
# [] en: Swimming
# [] en: Bathing close inshore
# [] en: Swimming
# [] en: boat from the Austrian ship Elizabeth
# [] en: boat from ship Josephine capsized in squall
# [] en: Painting a ship
# ['board'] en: Fell overboard
# [] en: Swimming alongside the schooner Catherine Wilcox
# [] en: Bathing
# [] en: Fishing
# ['Board'] en: Boarding a ship
# [] en: Dragging a shark
# [] en: Swimming
# [] en: Bathing
# [] en: Coming ashore on a hawser
# [] en: Boat swamped
# [] en: Standing / Bathing
# [] en: Swimming
# [] en: Bathing near whaling ship (bark A. R. Tucker of New Bedford, Massachusetts)
# [] en: Bathing
# [] en: Launching a boat
# [] en: Floating on back
# [] en: Swimming, caught in strong backwash & disappeared
# [] en: Bathing
# [] en: Swimming
# [] en: Swimming
# [] en: Trying to catch a wounded bird
# [] en: Bathing
# [] en: Swimming
# [] en: Swimming alongside the SS Kearsarge
# [] en: Bathing
# [] en: Boat of a Hawaiian brig was stove in by  whale
# [] en: Bathing alongside the American ship Thomas W. Sears
# [] en: Deserting the bark Nazarene
# [] en: Bathing
# [] en: Swimming
# [] en: Bathing
# [] en: Bathing
# [] en: Swimming
# [] en: Swimming
# [] en: Bathing
# [] en: 43-ton schooner Irene capsized & sank
# [] en: In boat being towed by ship, Karnak
# ['board'] en: Fell overboard
# [] en: Swimming
# [] en: Swimming
# [] en: Bathing
# ['board'] en: Jumped overboard while intoxicated
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: ship William Penn grounded & broke apart
# [] en: Bathing
# ['board'] en: Fell overboard from the Malacca
# ['board'] en: Fell overboard from the Sobella
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Commercial Salvage Diving
# [] en: Swimming
# [] en: Fell into the water
# [] en: Hard hat diving
# [] en: He was fighting a shark when his boat capsized & he disappeared
# ['board'] en: Knocked overboard
# [] en: Swimming
# [] en: Fishing
# ['board'] en: Fell overboard
# ['board'] en: Fell overboard
# [] en: Swimming
# [] en: Swimming from capsized boat
# [] en: Wreck of the steamship Birkenhead
# [] en: Swimming
# [] en: Vessel capsized, wading ashore carrying an oar
# [] en: Bathing
# [] en: Swimming
# [] en: Hard hat diving
# [] en: Bathing
# [] en: Bathing
# [] en: Swimming
# [] en: Attempting to rescue woman seized by shark
# [] en: Bathing
# [] en: boat capsized
# [] en: Swimming
# [] en: Standing
# [] en: Swimming
# [] en: Swimming
# [] en: Wreck of the Sovereign
# [] en: Swimming
# [] en: Boating
# [] en: Wreck of the USS Somers
# [] en: Fishing
# [] en: Seine netting
# [] en: Boat capsized
# [] en: Swimming
# ['board'] en: Fell overboard
# ['board'] en: Portuguese seaman fell overboard. Boat lowered to pick up with 1st mate & 4 crew, but done hurriedly & all were thrown into the water. As a second boat was lowered, a shark went after the 1st mate but he was rescued. Then the shark went after Mr. Andrews
# [] en: Harassing a shark
# [] en: Washed off catamaran in the surf
# [] en: Unknown, but it was said to be the "First known attack in Sydney Harbour"
# [] en: Bathing
# [] en: Swimming
# [] en: Sailing
# ['board'] en: Accidentally thrown overboard & treading water while awaiting rescue
# [] en: Sitting on gunwale of boat
# [] en: Attempting to rescue crew after whale upset their boat
# [] en: Bathing
# [] en: Washing his feet
# [] en: Bathing
# [] en: Hooking into a whale
# [] en: Swimming
# [] en: Fishing
# [] en: Bathing
# [] en: Boat capsized, clinging to line
# [] en: Fishing from dory, shark upset boat & he fell into the water
# [] en: Washing a dog
# [] en: Bathing
# [] en: Wreck of the schooner Driver
# [] en: British ship, Britannia,  was loading lumber. He was bathing
# [] en: Surfing
# [] en: Swimming
# [] en: Swimming
# ['board'] en: Jumped overboard
# [] en: Bathing
# [] en: HBM Magpie foundered in a squall
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Conch diver
# [] en: Swimming
# [] en: Swimming
# ['board'] en: Fell overboard
# [] en: a corsair's boat was overturned
# [] en: Fishing
# [] en: Swimming
# [] en: Surfing
# [] en: Murder
# [] en: Fishing
# [] en: Bathing
# [] en: Swimming
# ['board'] en: Fell overboard from a frigate & was swallowed by a shark. The captain fired a gun at the shark, and "the creature cast the man out of his throat."
# [] en: Swimming
# [] en: Pearl diving
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Bathing
# [] en: Bathing
# ['board'] en: Went overboard
# [] en: Wading
# [] en: Swimming
# [] en: Ship lay at anchor & man was working on its rudder
# ['board', 'board'] en: Man fell overboard from ship. Those on board threw a rope to him with a wooden block & were pulling him to the ship
# [] en: Swimming
# [] en: Pearl diving
# [] en: Sponge diving
# [] en: Ascending from a dive
# [] en: Washing his pig in preparation for a religious ceremony
# [] en: Shipwrecked Persian Fleet
# [] en: Diving
# [] en: Diving
# [] en: Swimming/
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming
# [] en: Swimming to canoe
# [] en: Fell into the water
# [] en: Diving
# [] en: Swimming
# [] en: Fishing for basking sharks
# [] en: Collecting fish
# [] en: Skin diving
# [] en: Snorkeling
# [] en: Shark tagging
# [] en: Surfing
# [] en: A dhow capsized
# [] en: Sponge diving
# [] en: Net-fishing
# [] en: Netting shrimp
# [] en: Bathing
# [] en: Fishing?
# [] en: Spearfishing
# [] en: Wade-fishing
# [] en: Free diving for sponges
# [] en: Fishing
# [] en: Swimming
# [] en: Helmet diving
# [] en: Pearl diving
# [] en: Spearfishing
# [] en: Kitesurfing
# [] en: yachtsman in a zodiac
# [] en: Diving
# [] en: Diving
# [] en: Fishing
# [] en: Diving
# [] en: Attempting to drive shark from area
# [] en: Skin diving. Grabbed shark's tail; shark turned & grabbed diver's ankle & began towing him to deep water
# [] en: Scuba diving
# [] en: Free diving
# [] en: Crossing river on a raft
# [] en: Free diving, collecting sand dollars
# [] en: Swimming
# [] en: Diving
# [] en: Canoeing
# [] en: Diving for trochus
# [] en: Pearl diving
# [] en: Swimming
# [] en: Spearfishing
# [] en: Skindiving
# [] en: Swimming from capsized pirogue
# [] en: Fishing from a small boat & put his hand in the water while holding a dead fish
# [] en: Swimming naked near a date palm where many dates fell into the water
# [] en: Swimming in section of river used for washing clothes & cooking utensils
# [] en: Spearfishing
# [] en: Swimming with fish attached to  belt
# [] en: Bathing
# [] en: Standing
# [] en: Testing movie camera in full diving dress
# [] en: Swimming near anchored ship
# [] en: Lashing logs together when he fell into the water
# ['board'] en: Shark fishing, knocked overboard
# [] en: Swimming
# [] en: Diving
# [] en: Fishing, wading with string of fish
# [] en: A group of survivors on a raft for 17-days
# [] en: Floating on his back
# [] en: Free diving
# [] en: Fishing in ankle-deep water
# [] en: Standing, washing rear wheels of his ambulance in ankle-deep water
# [] en: Swimming
# [] en: Diving
# [] en: Diving
# [] en: Diving
# [] en: Carrying a supposedly dead shark by its mouth
# [] en: Spent 8 days in dinghy
# [] en: Aircraft ditched in the sea, swimming ashore
# [] en: Bathing
# [] en: Wooden fishing boat
# [] en: Sponge diving
# [] en: Standing
# [] en: Swimming
# [] en: Wading
# [] en: Pearl diving
# [] en: Swimming in pool formed by construction of a wharf
# [] en: Fishing
# [] en: Swimming around anchored ship
# [] en: Crew swimming alongside their anchored ship
# [] en: 4 men were bathing
# [] en: Wreck of  large double sailing canoe
# [] en: Swimming
# [] en: Fishing
# [] en: Wading
# [] en: Swimming
# [] en: Fishing
# [] en: Fishing
# [] en: Fishing
# [] en: Swimming
# [] en: Diving
# [] en: Pearl diving
# [] en: Swimming
# [] en: Swimming

# %%
#busco las actividades que tienen surf y modalidades asociados como Surf-skiing, Kite-surfing o windsurfing
#ojo con Boogie boarding, Paddle boarding y Body boarding

# %%
str = "Lets go surfing to LA. I don't like surf"
x = re.search("surf", str)
print(x) 

print(re.search(r"[Ss]urf", str))
#encuentro problemas porque también aparece la palabra surface
# Out:
# <_sre.SRE_Match object; span=(8, 12), match='surf'>
# <_sre.SRE_Match object; span=(8, 12), match='surf'>

# %%
x='Resting on Surfang board'
print(re.search(r"[Ss]urf[\sib]", x))
#encuentro problemas porque también aparece la palabra surface
# Out:
# None

# %%
o='ojo con Boogie Board'
print(re.search(r"[Bb]oard", o))
# Out:
# <_sre.SRE_Match object; span=(15, 20), match='Board'>

# %%
"""Swimming after falling overboard
Scurfing (surfboard being  towed behind a boat)
Fishing for squid aboard the trawler Shikishima-Maru when the shark leapt into the boat
Sinking of the 40' Esperanza off St. Maartin with 36 refugees on board
Air Disaster - Piper aircraft crashed into the sea, killing all on board
Canoe with 3 men onboard sank
onboard y on board
Swimming, after falling off towed kneeboard
On board 51' fishing vessel One Ki
Onboard 21' powerboat that capsized in rough seas
Fell overboard  from the Taiwanese fishing trawler Lien Cheng Feu 
Sailboarding, fell into water 100 yards outside the breakwater
Motor launch Baby Princesa capsized with 22 people on board
 Small boat with 2 men onboard hit a submerged coral formation. Men began swimming to shore
    'board'] en: Fishing from 34' boat when pulled overboard by hooked shark
['board'] en: Hauling dead shark aboard, when another shark leapt out of the water & bit him
    S.S. Marine Sulphur Queen, laden with molten sulphur was bound from Beaumont, Texas for Norfolk, VA, when she disappeared with 39 on board """
# Out:
# "Swimming after falling overboard\nScurfing (surfboard being  towed behind a boat)\nFishing for squid aboard the trawler Shikishima-Maru when the shark leapt into the boat\nSinking of the 40' Esperanza off St. Maartin with 36 refugees on board\nAir Disaster - Piper aircraft crashed into the sea, killing all on board\nCanoe with 3 men onboard sank\nonboard y on board\nSwimming, after falling off towed kneeboard\nOn board 51' fishing vessel One Ki\nOnboard 21' powerboat that capsized in rough seas\nFell overboard  from the Taiwanese fishing trawler Lien Cheng Feu \nSailboarding, fell into water 100 yards outside the breakwater\nMotor launch Baby Princesa capsized with 22 people on board\n Small boat with 2 men onboard hit a submerged coral formation. Men began swimming to shore\n    'board'] en: Fishing from 34' boat when pulled overboard by hooked shark\n['board'] en: Hauling dead shark aboard, when another shark leapt out of the water & bit him\n    S.S. Marine Sulphur Queen, laden with molten sulphur was bound from Beaumont, Texas for Norfolk, VA, when she disappeared with 39 on board "

# %%
other=df['Activity'] == 'Surfing'

# %%
"""def otheractivity(e):
    categoría= 'Other activity'
    if re.search(r"[Ss]urf[\sib]", e) == None:
        e=categoría
    return e
    

x='Resting on surfaboard'
otheractivity(x)"""
# Out:
# 'def otheractivity(e):\n    categoría= \'Other activity\'\n    if re.search(r"[Ss]urf[\\sib]", e) == None:\n        e=categoría\n    return e\n    \n\nx=\'Resting on surfaboard\'\notheractivity(x)'

# %%
import src.functions as f

# %%
df['Activity']=df['Activity'].apply(f.other_activity)

# %%
df.head(10)
# Out:
#         Case Id  Year        Country        Activity
# 0  2016.09.18.c  2016            USA         Surfing
# 1  2016.09.18.b  2016            USA         Surfing
# 2  2016.09.18.a  2016            USA         Surfing
# 3    2016.09.17  2016      AUSTRALIA         Surfing
# 4    2016.09.15  2016      AUSTRALIA         Surfing
# 5  2016.09.15.R  2016      AUSTRALIA  Other activity
# 6    2016.09.11  2016            USA  Other activity
# 7    2016.09.07  2016            USA  Other activity
# 8    2016.09.06  2016  NEW CALEDONIA    Kite surfing
# 9  2016.09.05.b  2016            USA  Other activity

# %%
df["Activity"].value_counts().head(10)
# Out:
# Other activity                    4320
# Surfing                            898
# Body surfing                        48
# Windsurfing                         18
# Surf skiing                         12
# Surf fishing                        11
# Sitting on surfboard                 9
# Surfing (sitting on his board)       7
# Kite Surfing                         6
# Surf skiing                          6
# Name: Activity, dtype: int64

# %%
df['Activity']=df['Activity'].apply(f.surf_related)

# %%
df["Activity"].value_counts()
# Out:
# Other activity    4320
# Surf related      1118
# Name: Activity, dtype: int64

# %%
df.head(10)
# Out:
#         Case Id  Year        Country        Activity
# 0  2016.09.18.c  2016            USA    Surf related
# 1  2016.09.18.b  2016            USA    Surf related
# 2  2016.09.18.a  2016            USA    Surf related
# 3    2016.09.17  2016      AUSTRALIA    Surf related
# 4    2016.09.15  2016      AUSTRALIA    Surf related
# 5  2016.09.15.R  2016      AUSTRALIA  Other activity
# 6    2016.09.11  2016            USA  Other activity
# 7    2016.09.07  2016            USA  Other activity
# 8    2016.09.06  2016  NEW CALEDONIA    Surf related
# 9  2016.09.05.b  2016            USA  Other activity

# %%
set(df['Year'])
# Out:
# {0,
#  77,
#  1543,
#  1555,
#  1580,
#  1595,
#  1637,
#  1642,
#  1700,
#  1703,
#  1721,
#  1738,
#  1742,
#  1748,
#  1749,
#  1758,
#  1764,
#  1767,
#  1771,
#  1776,
#  1779,
#  1787,
#  1788,
#  1800,
#  1811,
#  1812,
#  1816,
#  1817,
#  1825,
#  1826,
#  1827,
#  1828,
#  1829,
#  1830,
#  1831,
#  1832,
#  1834,
#  1835,
#  1837,
#  1839,
#  1840,
#  1841,
#  1842,
#  1844,
#  1845,
#  1846,
#  1847,
#  1848,
#  1849,
#  1850,
#  1851,
#  1852,
#  1853,
#  1854,
#  1855,
#  1856,
#  1858,
#  1859,
#  1860,
#  1861,
#  1862,
#  1863,
#  1864,
#  1865,
#  1866,
#  1867,
#  1868,
#  1869,
#  1870,
#  1871,
#  1872,
#  1873,
#  1874,
#  1875,
#  1876,
#  1877,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016}

# %%
stats = df.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#        count         mean         std  min     25%     50%     75%     max  \
# Year  5438.0  1930.118978  275.719038  0.0  1944.0  1978.0  2004.0  2016.0
#
#        IQR
# Year  60.0

# %%
outliers = pd.DataFrame(columns=df.columns)

for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 3
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = df[(df[col] < lower) | 
  
                   (df[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)

# %%
outliers.head(50)
# Out:
#             Activity       Case Id                   Country Outlier  Year
# 5843  Other activity    1758.00.00         MEDITERRANEAN SEA    Year  1758
# 5844  Other activity    1749.00.00                      CUBA    Year  1749
# 5846  Other activity    1748.00.00                    PANAMA    Year  1748
# 5847  Other activity    1742.12.17                   Unknown    Year  1742
# 5848  Other activity  1738.04.06.R                     ITALY    Year  1738
# 5850  Other activity    1721.06.00                     ITALY    Year  1721
# 5851  Other activity    1703.03.26                  BARBADOS    Year  1703
# 5853  Other activity  1700.00.00.b                    FRANCE    Year  1700
# 5854  Other activity  1700.00.00.a                  BARBADOS    Year  1700
# 5855  Other activity  1642.00.00.b                    GUINEA    Year  1642
# 5857  Other activity  1637.00.00.R                     INDIA    Year  1637
# 5859  Other activity    1642.00.00                       USA    Year  1642
# 5860  Other activity    1595.00.00                     INDIA    Year  1595
# 5861  Other activity  1580.01.10.R  Between PORTUGAL & INDIA    Year  1580
# 5862  Other activity    1555.00.00                   Unknown    Year  1555
# 5864  Other activity    1543.00.00                 VENEZUELA    Year  1543
# 5866  Other activity    0077.00.00                   Unknown    Year    77
# 5868  Other activity        0.0214                   Unknown    Year     0
# 5869  Other activity        0.0336                    GREECE    Year     0
# 5870  Other activity        0.0493                    GREECE    Year     0
# 5872  Other activity       ND-0153                     KENYA    Year     0
# 5873  Other activity       ND-0152                     KENYA    Year     0
# 5874  Other activity       ND-0151                    PANAMA    Year     0
# 5875  Other activity       ND-0150                   URUGUAY    Year     0
# 5876  Other activity       ND-0149                   URUGUAY    Year     0
# 5877  Other activity       ND-0148                       USA    Year     0
# 5878  Other activity       ND-1940          PAPUA NEW GUINEA    Year     0
# 5880  Other activity       ND-0138                 AUSTRALIA    Year     0
# 5881  Other activity       ND-0136                       USA    Year     0
# 5883  Other activity       ND-0134                    GREECE    Year     0
# 5884  Other activity       ND-0133                       USA    Year     0
# 5886  Other activity       ND-0130                   LEBANON    Year     0
# 5887  Other activity       ND-0129                     SPAIN    Year     0
# 5888  Other activity       ND-0127                     SUDAN    Year     0
# 5890  Other activity       ND-0123                       USA    Year     0
# 5891    Surf related       ND-0122                       USA    Year     0
# 5892  Other activity       ND-0119                  DJIBOUTI    Year     0
# 5893  Other activity       ND-0118                     LIBYA    Year     0
# 5894  Other activity       ND-0116                 AUSTRALIA    Year     0
# 5896  Other activity       nd-0114                   Unknown    Year     0
# 5897  Other activity       ND-0113                   VIETNAM    Year     0
# 5898  Other activity       ND-0111                 SRI LANKA    Year     0
# 5899  Other activity       ND.0110                 VENEZUELA    Year     0
# 5900  Other activity       ND-0109                       USA    Year     0
# 5901  Other activity       ND-0108                    GREECE    Year     0
# 5902  Other activity       ND-0107                MOZAMBIQUE    Year     0
# 5903  Other activity       ND-0106              SOUTH AFRICA    Year     0
# 5904  Other activity       ND.0104                 AUSTRALIA    Year     0
# 5905  Other activity       ND.0102                   BAHREIN    Year     0
# 5906  Other activity       ND.0100                   BAHAMAS    Year     0
